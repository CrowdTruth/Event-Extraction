# %% [markdown]
# # CrowdTruth for Sparse Multiple Choice Tasks: Event Extraction

# %%
import pandas as pd
file_name = "f1328291"
test_data = pd.read_csv("../../data/pilot_crowd_data/raw_data/" + file_name + ".csv")
test_data.head()
# Out:
#      _unit_id         _created_at         _id         _started_at  _tainted  \
# 0  2039966184  12/9/2018 19:15:27  4323139152  12/9/2018 19:14:50     False
# 1  2039966184  12/9/2018 19:39:10  4323164575  12/9/2018 19:38:54     False
# 2  2039966184  12/9/2018 19:51:34  4323176316  12/9/2018 19:51:16     False
# 3  2039966184  12/9/2018 20:06:31  4323196737  12/9/2018 20:06:16     False
# 4  2039966184  12/9/2018 20:08:01  4323198015  12/9/2018 20:07:47     False
#
#      _channel  _trust  _worker_id _country _region  ...    \
# 0       elite     1.0    39017656      CAN      BC  ...
# 1  coinworker     1.0    41920197      USA      NY  ...
# 2       elite     1.0    44369755      USA      TX  ...
# 3       elite     1.0    44269380      USA      MN  ...
# 4  coinworker     1.0    44174450      CAN      QC  ...
#
#                                   lowercase_sentence pos_tags  \
# 0  bp expects the share buyback programme could t...       16
# 1  bp expects the share buyback programme could t...       16
# 2  bp expects the share buyback programme could t...       16
# 3  bp expects the share buyback programme could t...       16
# 4  bp expects the share buyback programme could t...       16
#
#    selectedtags_desc_gold                                           sentence  \
# 0                     NaN  BP expects the share buyback programme could t...
# 1                     NaN  BP expects the share buyback programme could t...
# 2                     NaN  BP expects the share buyback programme could t...
# 3                     NaN  BP expects the share buyback programme could t...
# 4                     NaN  BP expects the share buyback programme could t...
#
#   sentence_id                                     stanford_lemma  \
# 0           6  bp expect the share buyback programme could ta...
# 1           6  bp expect the share buyback programme could ta...
# 2           6  bp expect the share buyback programme could ta...
# 3           6  bp expect the share buyback programme could ta...
# 4           6  bp expect the share buyback programme could ta...
#
#                                 stanford_lower_lemma  \
# 0  bp expect the share buyback programme could ta...
# 1  bp expect the share buyback programme could ta...
# 2  bp expect the share buyback programme could ta...
# 3  bp expect the share buyback programme could ta...
# 4  bp expect the share buyback programme could ta...
#
#                                    stanford_pos_tag  time_expressions tokens
# 0  NN VBZ DT NN NN NN MD VB IN CD CC CD NNS TO VB .                 2     16
# 1  NN VBZ DT NN NN NN MD VB IN CD CC CD NNS TO VB .                 2     16
# 2  NN VBZ DT NN NN NN MD VB IN CD CC CD NNS TO VB .                 2     16
# 3  NN VBZ DT NN NN NN MD VB IN CD CC CD NNS TO VB .                 2     16
# 4  NN VBZ DT NN NN NN MD VB IN CD CC CD NNS TO VB .                 2     16
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Declaring a pre-processing configuration
#
# The pre-processing configuration defines how to interpret the raw crowdsourcing input. To do this, we need to define a configuration class. First, we import the default CrowdTruth configuration class:

# %%
import crowdtruth
from crowdtruth.configuration import DefaultConfig

# %% [markdown]
# Our test class inherits the default configuration `DefaultConfig`, while also declaring some additional attributes that are specific to the Relation Extraction task:
#
# * **`inputColumns`:** list of input columns from the .csv file with the input data
# * **`outputColumns`:** list of output columns from the .csv file with the answers from the workers
# * **`annotation_separator`:** string that separates between the crowd annotations in `outputColumns`
# * **`open_ended_task`:** boolean variable defining whether the task is open-ended (i.e. the possible crowd annotations are not known beforehand, like in the case of free text input); in the task that we are processing, workers pick the answers from a pre-defined list, therefore the task is not open ended, and this variable is set to `False`
# * **`annotation_vector`:** list of possible crowd answers, mandatory to declare when `open_ended_task` is `False`; for our task, this is the list of all relations that were given as input to the crowd in at least one sentence
# * **`processJudgments`:** method that defines processing of the raw crowd data; for this task, we process the crowd answers to correspond to the values in `annotation_vector`
#
# The complete configuration class is declared below:

# %%
class TestConfig(DefaultConfig):
    inputColumns = ["doc_id", "time_expressions", "sentence", "lowercase_sentence", "sentence_id", "all_runs_times"]
    outputColumns = ["selectedtags_desc"]
    
    annotation_separator = ","
        
    # processing of a closed task
    open_ended_task = True
    
    def processJudgments(self, judgments):
        # pre-process output to match the values in annotation_vector
        for col in self.outputColumns:
            # transform to lowercase
            judgments[col] = judgments[col].apply(lambda x: str(x).lower())
            # remove square brackets from annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('[',''))
            judgments[col] = judgments[col].apply(lambda x: str(x).replace(']',''))
            # remove the quotes around the annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('"',''))
        return judgments

# %% [markdown]
# ## Pre-processing the input data
#
# After declaring the configuration of our input file, we are ready to pre-process the crowd data:

# %%
data_open, config = crowdtruth.load(
    file = "../pilot_data/" + file_name + ".csv",
    config = TestConfig()
)

data_open['judgments'].head()
# Out:
#                                      output.selectedtags_desc  \
# judgment
# 4323139152  {u'18 months__65__74': 1, u'12 and 18 months__...
# 4323164575                   {u'12 and 18 months__58__74': 1}
# 4323176316                   {u'12 and 18 months__58__74': 1}
# 4323196737                   {u'12 and 18 months__58__74': 1}
# 4323198015                   {u'12 and 18 months__58__74': 1}
#
#             output.selectedtags_desc.count  output.selectedtags_desc.unique  \
# judgment
# 4323139152                               3                                3
# 4323164575                               1                                1
# 4323176316                               1                                1
# 4323196737                               1                                1
# 4323198015                               1                                1
#
#                      submitted             started    worker        unit  \
# judgment
# 4323139152 2018-12-09 19:15:27 2018-12-09 19:14:50  39017656  2039966184
# 4323164575 2018-12-09 19:39:10 2018-12-09 19:38:54  41920197  2039966184
# 4323176316 2018-12-09 19:51:34 2018-12-09 19:51:16  44369755  2039966184
# 4323196737 2018-12-09 20:06:31 2018-12-09 20:06:16  44269380  2039966184
# 4323198015 2018-12-09 20:08:01 2018-12-09 20:07:47  44174450  2039966184
#
#             duration                     job
# judgment
# 4323139152        37  ../pilot_data/f1328291
# 4323164575        16  ../pilot_data/f1328291
# 4323176316        18  ../pilot_data/f1328291
# 4323196737        15  ../pilot_data/f1328291
# 4323198015        14  ../pilot_data/f1328291

# %% [markdown]
# ## Computing the CrowdTruth metrics
#
# The pre-processed data can then be used to calculate the CrowdTruth metrics:

# %%
results_open = crowdtruth.run(data_open, config)

# %% [markdown]
# `results` is a dict object that contains the quality metrics for sentences, events and crowd workers.
#
# The **sentence metrics** are stored in `results["units"]`:

# %%
results_open["units"].head()
# Out:
#             duration                               input.all_runs_times  \
# unit
# 2039966184     25.55  18 months__65__74###12 and 18 months__58__74##...
# 2039966185     22.00                  1953__113__117###1953 .__113__119
# 2039966186     21.35                                       1953__71__75
# 2039966187     22.80      1957 - 58__60__69###1957__60__64###58__67__69
# 2039966188     28.15                   1984__19__23###last June__75__84
#
#                  input.doc_id  \
# unit
# 2039966184   bbc_20130322_332
# 2039966185  bbc_20130322_1150
# 2039966186  bbc_20130322_1150
# 2039966187  bbc_20130322_1150
# 2039966188  bbc_20130322_1150
#
#                                      input.lowercase_sentence  \
# unit
# 2039966184  bp expects the share buyback programme could t...
# 2039966185  new zealand-born mr lowe was part of the team ...
# 2039966186  the last surviving member of the team which fi...
# 2039966187  mr lowe also took part in the trans-antarctic ...
# 2039966188  the last british climbing member of the 1953 t...
#
#                                                input.sentence  \
# unit
# 2039966184  BP expects the share buyback programme could t...
# 2039966185  New Zealand-born Mr Lowe was part of the team ...
# 2039966186  The last surviving member of the team which fi...
# 2039966187  Mr Lowe also took part in the trans-Antarctic ...
# 2039966188  The last British climbing member of the 1953 t...
#
#             input.sentence_id  input.time_expressions                     job  \
# unit
# 2039966184                  6                       2  ../pilot_data/f1328291
# 2039966185                  2                       1  ../pilot_data/f1328291
# 2039966186                  0                       1  ../pilot_data/f1328291
# 2039966187                  4                       2  ../pilot_data/f1328291
# 2039966188                 19                       1  ../pilot_data/f1328291
#
#                                      output.selectedtags_desc  \
# unit
# 2039966184  {u'12 and 18 months__58__74': 18, u'12__58__60...
# 2039966185    {u'1953 .__113__119': 9, u'1953__113__117': 17}
# 2039966186               {u'1953__71__75': 19, u'no_time': 1}
# 2039966187  {u'1957 - 58__60__69': 18, u'58__67__69': 3, u...
# 2039966188    {u'1984__19__23': 10, u'last june__75__84': 16}
#
#             output.selectedtags_desc.annotations  \
# unit
# 2039966184                                    27
# 2039966185                                    26
# 2039966186                                    20
# 2039966187                                    28
# 2039966188                                    26
#
#             output.selectedtags_desc.unique_annotations  worker       uqs  \
# unit
# 2039966184                                            3      20  0.739090
# 2039966185                                            2      20  0.700695
# 2039966186                                            2      20  0.922057
# 2039966187                                            3      20  0.726518
# 2039966188                                            2      20  0.670435
#
#                                         unit_annotation_score  uqs_initial  \
# unit
# 2039966184  {u'12 and 18 months__58__74': 0.911690071615, ...     0.729805
# 2039966185  {u'1953 .__113__119': 0.465169410743, u'1953__...     0.696826
# 2039966186  {u'1953__71__75': 0.961533119359, u'no_time': ...     0.900000
# 2039966187  {u'1957 - 58__60__69': 0.917115082471, u'58__6...     0.711016
# 2039966188  {u'1984__19__23': 0.511194836711, u'last june_...     0.659984
#
#                                 unit_annotation_score_initial
# unit
# 2039966184  {u'12 and 18 months__58__74': 0.9, u'12__58__6...
# 2039966185  {u'1953 .__113__119': 0.45, u'1953__113__117':...
# 2039966186          {u'1953__71__75': 0.95, u'no_time': 0.05}
# 2039966187  {u'1957 - 58__60__69': 0.9, u'58__67__69': 0.1...
# 2039966188  {u'1984__19__23': 0.5, u'last june__75__84': 0.8}

# %% [markdown]
# The `uqs` column in `results["units"]` contains the **sentence quality scores**, capturing the overall workers agreement over each sentence. Here we plot its histogram:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(results_open["units"]["uqs"])
plt.xlabel("Sentence Quality Score")
plt.ylabel("Sentences")
# Out:
# Text(0,0.5,u'Sentences')

# %% [markdown]
# The `unit_annotation_score` column in `results["units"]` contains the **sentence-relation scores**, capturing the likelihood that a relation is expressed in a sentence. For each sentence, we store a dictionary mapping each relation to its sentence-relation score.

# %%
results_open["units"]["unit_annotation_score"].head(10)
# Out:
# unit
# 2039966184    {u'12 and 18 months__58__74': 0.911690071615, ...
# 2039966185    {u'1953 .__113__119': 0.465169410743, u'1953__...
# 2039966186    {u'1953__71__75': 0.961533119359, u'no_time': ...
# 2039966187    {u'1957 - 58__60__69': 0.917115082471, u'58__6...
# 2039966188    {u'1984__19__23': 0.511194836711, u'last june_...
# 2039966189    {u'1995__23__27': 0.634245982412, u'the 99th d...
# 2039966190    {u'2003__25__29': 1.0, u'2003 .__25__31': 0.30...
# 2039966191                                {u'2003__6__10': 1.0}
# 2039966192                             {u'2005__132__136': 1.0}
# 2039966193    {u'2005__132__136': 0.441310636889, u'no_time'...
# Name: unit_annotation_score, dtype: object

# %% [markdown]
# The **worker metrics** are stored in `results["workers"]`:

# %%
results_open["workers"].head()
# Out:
#            duration  job  judgment  unit       wqs       wwa       wsa  \
# worker
# 6082058   23.405405    1        37    37  0.745096  0.823027  0.905312
# 6336109   52.733333    1        45    45  0.587642  0.727894  0.807318
# 11131207  68.900000    1        40    40  0.837478  0.865273  0.967877
# 13300986  10.333333    1         6     6  0.667293  0.787028  0.847864
# 15117831   7.000000    1         3     3  0.771704  0.817506  0.943974
#
#           wqs_initial  wwa_initial  wsa_initial
# worker
# 6082058      0.669480     0.767048     0.872801
# 6336109      0.538130     0.681891     0.789173
# 11131207     0.790357     0.824205     0.958932
# 13300986     0.580463     0.721275     0.804773
# 15117831     0.669573     0.736620     0.908980

# %% [markdown]
# The `wqs` columns in `results["workers"]` contains the **worker quality scores**, capturing the overall agreement between one worker and all the other workers.

# %%
plt.hist(results_open["workers"]["wqs"])
plt.xlabel("Worker Quality Score")
plt.ylabel("Workers")
# Out:
# Text(0,0.5,u'Workers')

# %% [markdown]
# ## Save crowd results in a csv file

# %%
rows = []
header = list(results_open["units"])
header.extend(["validated_time", "no_of_annotations", "validated_time_final_score", "validated_time_initial_score"])

rows.append(header)

for i in range(len(results_open["units"].index)):
    keys = []
    all_time_runs = results_open["units"]["input.all_runs_times"].iloc[i].lower().split("###")
    keys.extend(all_time_runs)
    keys.append("no_time")
    
    for j in range(len(keys)):
        row = list(results_open["units"].iloc[i])
        row.append(keys[j])
        row.append(results_open["units"]["output.selectedtags_desc"].iloc[i][keys[j].lower()])
        row.append(results_open["units"]["unit_annotation_score"].iloc[i][keys[j].lower()])
        row.append(results_open["units"]["unit_annotation_score_initial"].iloc[i][keys[j].lower()])
    
        rows.append(row)
        
        
import csv

with open('../pilot_data/' + file_name + '_units_open.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(rows)

# %% [markdown]
# ## Comparison with Expert Annotations

# %%
# expert annotations in TempEval-3 Platinum dataset
import numpy as np
           
expert_data = pd.read_csv("../TempEval3-data/TE3-Platinum_time.csv")
crowd_data = pd.read_csv("../pilot_data/" + file_name + "_units_open.csv")
crowd_data["Experts"] = pd.Series(np.random.randn(len(crowd_data.index)), index=crowd_data.index)

for i in range(len(crowd_data.index)):
    subset = expert_data[(expert_data["Doc Id"].str.lower() == crowd_data["input.doc_id"].iloc[i].lower()) & (expert_data["Sentence Id"] == crowd_data["input.sentence_id"].iloc[i])]# & (str(str(expert_data["Lowercase Token"]) + "__" + str(expert_data["Start Offset"]) + "__" + str(expert_data["End Offset"])) == str(crowd_data["validated_event"].iloc[i]))]
    found = False
    for j in range(len(subset.index)):
        if str(str(subset["Lowercase Token"].iloc[j]) + "__" + str(subset["Start Offset"].iloc[j]) + "__" + str(subset["End Offset"].iloc[j])) == crowd_data["validated_time"].iloc[i]:
            found = True
            break
    if found == True:
        crowd_data["Experts"].iloc[i] = 1
    else:
        crowd_data["Experts"].iloc[i] = 0
crowd_data.to_csv("../pilot_data/" + file_name + "_units_open.csv", index=False)
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import eval_crowd_results as eval_script

crowd = pd.read_csv('../pilot_data/' + file_name + '_units_open.csv')
eval_file = eval_script.compute_crowd_performance(crowd, "validated_time_final_score")
     
with open('../pilot_data/eval_' + file_name + '_units_open.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(eval_file)
    
eval_main = pd.read_csv("../pilot_data/eval_" + file_name + "_units_open.csv")
eval_main
# Out:
#     Thresh  TP   TN  FP  FN  Precision    Recall  Accuracy  F1-score
# 0     0.05  58   47  59   0   0.495726  1.000000  0.640244  0.662857
# 1     0.10  57   50  56   1   0.504425  0.982759  0.652439  0.666667
# 2     0.15  57   53  53   1   0.518182  0.982759  0.670732  0.678571
# 3     0.20  56   54  52   2   0.518519  0.965517  0.670732  0.674699
# 4     0.25  56   57  49   2   0.533333  0.965517  0.689024  0.687117
# 5     0.30  56   59  47   2   0.543689  0.965517  0.701220  0.695652
# 6     0.35  55   65  41   3   0.572917  0.948276  0.731707  0.714286
# 7     0.40  51   68  38   7   0.573034  0.879310  0.725610  0.693878
# 8     0.45  50   76  30   8   0.625000  0.862069  0.768293  0.724638
# 9     0.50  50   82  24   8   0.675676  0.862069  0.804878  0.757576
# 10    0.55  47   86  20  11   0.701493  0.810345  0.810976  0.752000
# 11    0.60  42   93  13  16   0.763636  0.724138  0.823171  0.743363
# 12    0.65  39   95  11  19   0.780000  0.672414  0.817073  0.722222
# 13    0.70  37   97   9  21   0.804348  0.637931  0.817073  0.711538
# 14    0.75  33   98   8  25   0.804878  0.568966  0.798780  0.666667
# 15    0.80  32   99   7  26   0.820513  0.551724  0.798780  0.659794
# 16    0.85  26   99   7  32   0.787879  0.448276  0.762195  0.571429
# 17    0.90  23  101   5  35   0.821429  0.396552  0.756098  0.534884
# 18    0.95  17  105   1  41   0.944444  0.293103  0.743902  0.447368
# 19    1.00  14  105   1  44   0.933333  0.241379  0.725610  0.383562

# %% [markdown]
# ## Open to Closed Task Transformation
#
# The goal of this crowdsourcing task is to understand how clearly a word or a word phrase is expressing an event or an action across all the sentences in the dataset and not at the level of a single sentence as previously. Therefore, in the remainder of this tutorial we show how to *translate an open task to a closed task* by processing *both the input units and the annotations* of a crowdsourcing task.
#
# The answers from the crowd are stored in the `selected_events` column.

# %%
test_data["selectedtags_desc"][0:30]
# Out:
# 0                          ["12 and 18 months__58__74"]
# 1     ["18 months__65__74","12 and 18 months__58__74...
# 2     ["18 months__65__74","12 and 18 months__58__74...
# 3                          ["12 and 18 months__58__74"]
# 4     ["18 months__65__74","12 and 18 months__58__74...
# 5     ["18 months__65__74","12 and 18 months__58__74...
# 6                                 ["18 months__65__74"]
# 7                          ["12 and 18 months__58__74"]
# 8                          ["12 and 18 months__58__74"]
# 9                          ["12 and 18 months__58__74"]
# 10     ["18 months__65__74","12 and 18 months__58__74"]
# 11    ["18 months__65__74","12 and 18 months__58__74...
# 12                         ["12 and 18 months__58__74"]
# 13                         ["12 and 18 months__58__74"]
# 14    ["18 months__65__74","12 and 18 months__58__74...
# 15    ["18 months__65__74","12 and 18 months__58__74...
# 16                         ["12 and 18 months__58__74"]
# 17                         ["12 and 18 months__58__74"]
# 18                         ["12 and 18 months__58__74"]
# 19                         ["12 and 18 months__58__74"]
# 20                ["1953__113__117","1953 .__113__119"]
# 21                ["1953__113__117","1953 .__113__119"]
# 22                                   ["1953__113__117"]
# 23                ["1953__113__117","1953 .__113__119"]
# 24                ["1953__113__117","1953 .__113__119"]
# 25                                   ["1953__113__117"]
# 26                                   ["1953__113__117"]
# 27                                          ["no_time"]
# 28                ["1953__113__117","1953 .__113__119"]
# 29                                   ["1953__113__117"]
# Name: selectedtags_desc, dtype: object

# %% [markdown]
# As you already know, each word can be expressed in a canonical form, i.e., as a lemma. For example, the words: *run*, *runs*, *running*, they all have the lemma *run*. As you can see in the previous cell, events in text can appear under multiple forms. To evaluate the clarity of each event, we will process both the input units and the crowd annotations to refer to a word in its canonical form, i.e., we will lemmatize them.

# %% [markdown]
# Following, we define the function used to lemmatize the options that are shown to the workers in the crowdsourcing task:

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

def nltk2wn_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None
    
def lemmatize_events(event):
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(str(event.lower().split("__")[0])))  
    wn_tagged = map(lambda x: (str(x[0]), nltk2wn_tag(x[1])), nltk_tagged)
    res_words = []
                
    for word, tag in wn_tagged:
        if tag is None:            
            res_word = wordnet._morphy(str(word), wordnet.NOUN)
            if res_word == []:
                res_words.append(str(word))
            else:
                if len(res_word) == 1:
                    res_words.append(str(res_word[0]))
                else:
                    res_words.append(str(res_word[1]))
        else:
            res_word = wordnet._morphy(str(word), tag)
            if res_word == []:
                res_words.append(str(word))
            else: 
                if len(res_word) == 1:
                    res_words.append(str(res_word[0]))
                else:
                    res_words.append(str(res_word[1]))
    
    lematized_keyword = " ".join(res_words)
    return lematized_keyword
# Out:
# [nltk_data] Downloading package punkt to /Users/oanainel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

def nltk2wn_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None
# Out:
# [nltk_data] Downloading package punkt to /Users/oanainel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# The following functions create the values of the annotation vector and extracts the lemma of the events selected by each worker.

# %%
def define_annotation_vector(eventsList):  
    events = []
    for i in range(len(eventsList)):
        currentEvents = eventsList[i].split("###")
        
        for j in range(len(currentEvents)):
            if currentEvents[j] != "no_time":
                lematized_keyword = lemmatize_events(currentEvents[j])
                
                if lematized_keyword not in events:
                    events.append(lematized_keyword)
    events.append("no_time")   
    return events

def lemmatize_keywords(keywords, separator):
    keywords_list = keywords.split(separator)
    lematized_keywords = []
    
    for keyword in keywords_list:
        lematized_keyword = lemmatize_events(keyword)
        lematized_keywords.append(lematized_keyword)
    
    return separator.join(lematized_keywords)

# %%
class TestConfig(DefaultConfig):
    inputColumns = ["doc_id", "time_expressions", "sentence", "lowercase_sentence", "sentence_id", "all_runs_times"]
    outputColumns = ["selectedtags_desc"]
    
    annotation_separator = ","
        
    # processing of a closed task
    open_ended_task = False
    annotation_vector = define_annotation_vector(test_data["all_runs_times"])
    print(annotation_vector)
    
    def processJudgments(self, judgments):
        # pre-process output to match the values in annotation_vector
        for col in self.outputColumns:
            # transform to lowercase
            judgments[col] = judgments[col].apply(lambda x: str(x).lower())
            # remove square brackets from annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace("[",""))
            judgments[col] = judgments[col].apply(lambda x: str(x).replace("]",""))
            # remove the quotes around the annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('"',''))
            judgments[col] = judgments[col].apply(lambda x: lemmatize_keywords(str(x), self.annotation_separator))
        return judgments
# Out:
# ['18 month', '12 and 18 month', '12', 'and', '1953', '1953 .', '1957 - 58', '1957', '58', '1984', 'last june', '1995', '100 day', 'the 99th day', 'day', '99th day', '100', '2003', '2003 .', '2005', 'former', '2007', 'once', '2007 .', '2008', 'in', '2008 .', '2009 - 2010', '2009', '2010', '2011', '2030', 'now', '20th century', 'century', 'the 20th century', '3:07:35', '6 month', 'month', 'each season', 'age 6 month', '60 year', 'year', 'a term', 'a week', 'summer', 'over a week', 'an hour', 'annually', 'april 7', 'four-week', 'at the time', 'august', 'july', 'july .', 'current', 'currently', 'digital', 'early 2011', 'the 26.2-mile event - set day', 'one second', 'early 2011 .', 'second', 'early august', 'early december', 'the end of year', 'a month earlier than usual', 'a month earlier than', 'early december _ a month earlier', 'a month', 'year .', 'a month earlier', 'early december _ a month', 'early this year', 'seven year', 'this year', 'almost seven year', 'seven year .', 'eight year', ';', 'eight year from now', 'every morning', 'morning', 'feb. 28', 'the next decade', 'the next decade .', 'five year', 'four year ago', 'higher-grade fuel four year ago', 'four year ago .', 'friday afternoon', 'no_time']

# %%
data_closed, config = crowdtruth.load(
    file = "../pilot_data/" + file_name + ".csv",
    config = TestConfig()
)

data_closed['judgments'].head()
# Out:
#                                      output.selectedtags_desc  \
# judgment
# 4294570217  {u'12 and 18 month': 1, u'18 month': 0, u'12':...
# 4294740016  {u'18 month': 1, u'12 and 18 month': 1, u'12':...
# 4295006565  {u'18 month': 1, u'12 and 18 month': 1, u'12':...
# 4295198038  {u'12 and 18 month': 1, u'18 month': 0, u'12':...
# 4295459374  {u'18 month': 1, u'12 and 18 month': 1, u'12':...
#
#             output.selectedtags_desc.count  output.selectedtags_desc.unique  \
# judgment
# 4294570217                               1                               92
# 4294740016                               3                               92
# 4295006565                               3                               92
# 4295198038                               1                               92
# 4295459374                               3                               92
#
#                      submitted             started    worker        unit  \
# judgment
# 4294570217 2018-11-30 12:25:42 2018-11-30 12:25:28   4316379  2031004659
# 4294740016 2018-11-30 13:43:01 2018-11-30 13:42:42  43960360  2031004659
# 4295006565 2018-11-30 15:51:41 2018-11-30 15:51:01  39017656  2031004659
# 4295198038 2018-11-30 17:20:44 2018-11-30 17:20:20  44378354  2031004659
# 4295459374 2018-11-30 19:21:30 2018-11-30 19:21:20  43294773  2031004659
#
#             duration                                            job
# judgment
# 4294570217        14  ../pilot_data/f1323741_temporal_allmotivation
# 4294740016        19  ../pilot_data/f1323741_temporal_allmotivation
# 4295006565        40  ../pilot_data/f1323741_temporal_allmotivation
# 4295198038        24  ../pilot_data/f1323741_temporal_allmotivation
# 4295459374        10  ../pilot_data/f1323741_temporal_allmotivation

# %%
results_closed = crowdtruth.run(data_closed, config)

# %%
results_closed["annotations"]
# Out:
#                                  output.selectedtags_desc           aqs  \
# 100                                                  1000  1.942163e-01
# 100 day                                              1000  7.178636e-01
# 12                                                   1000  3.490904e-01
# 12 and 18 month                                      1000  9.479105e-01
# 18 month                                             1000  4.632623e-01
# 1953                                                 1000  9.313542e-01
# 1953 .                                               1000  4.261686e-01
# 1957                                                 1000  4.299263e-01
# 1957 - 58                                            1000  1.000000e+00
# 1984                                                 1000  7.346547e-01
# 1995                                                 1000  7.481167e-01
# 2003                                                 1000  9.316287e-01
# 2003 .                                               1000  3.374919e-01
# 2005                                                 1000  8.953239e-01
# 2007                                                 1000  8.014450e-01
# 2007 .                                               1000  4.567347e-01
# 2008                                                 1000  8.960307e-01
# 2008 .                                               1000  3.992636e-01
# 2009                                                 1000  8.492602e-01
# 2009 - 2010                                          1000  9.700702e-01
# 2010                                                 1000  9.230210e-01
# 2011                                                 1000  8.940614e-01
# 2030                                                 1000  7.944524e-01
# 20th century                                         1000  6.178473e-01
# 3:07:35                                              1000  9.220969e-01
# 58                                                   1000  3.674652e-01
# 6 month                                              1000  7.441724e-01
# 60 year                                              1000  3.950118e-01
# 99th day                                             1000  5.537433e-01
# ;                                                    1000  1.000000e-08
# ...                                                   ...           ...
# former                                               1000  6.837867e-01
# four year ago                                        1000  8.485218e-01
# four year ago .                                      1000  3.692811e-01
# four-week                                            1000  6.353123e-01
# friday afternoon                                     1000  1.000000e+00
# higher-grade fuel four year ago                      1000  2.391561e-01
# in                                                   1000  4.378015e-02
# july                                                 1000  7.368262e-01
# july .                                               1000  2.808264e-01
# last june                                            1000  9.347021e-01
# month                                                1000  3.907678e-01
# morning                                              1000  5.449910e-01
# no_time                                              1000  2.826942e-01
# now                                                  1000  5.562533e-01
# once                                                 1000  3.775331e-01
# one second                                           1000  6.709521e-01
# over a week                                          1000  4.668604e-01
# second                                               1000  3.004713e-01
# seven year                                           1000  5.970578e-01
# seven year .                                         1000  3.175565e-01
# summer                                               1000  7.453964e-01
# the 20th century                                     1000  3.293458e-01
# the 26.2-mile event - set day                        1000  3.932302e-01
# the 99th day                                         1000  6.103207e-01
# the end of year                                      1000  6.340675e-01
# the next decade                                      1000  8.991349e-01
# the next decade .                                    1000  3.654835e-01
# this year                                            1000  5.718775e-01
# year                                                 1000  3.095312e-01
# year .                                               1000  2.390589e-01
#
#                                   aqs_initial
# 100                              1.578947e-01
# 100 day                          6.842105e-01
# 12                               3.157895e-01
# 12 and 18 month                  9.473684e-01
# 18 month                         4.210526e-01
# 1953                             8.883495e-01
# 1953 .                           4.210526e-01
# 1957                             3.684211e-01
# 1957 - 58                        1.000000e+00
# 1984                             7.322335e-01
# 1995                             6.842105e-01
# 2003                             9.033816e-01
# 2003 .                           3.157895e-01
# 2005                             8.571429e-01
# 2007                             7.368421e-01
# 2007 .                           4.210526e-01
# 2008                             8.556962e-01
# 2008 .                           3.991416e-01
# 2009                             8.121086e-01
# 2009 - 2010                      9.473684e-01
# 2010                             8.915432e-01
# 2011                             8.477496e-01
# 2030                             7.368421e-01
# 20th century                     5.844156e-01
# 3:07:35                          8.947368e-01
# 58                               3.157895e-01
# 6 month                          6.842105e-01
# 60 year                          3.684211e-01
# 99th day                         5.263158e-01
# ;                                1.000000e-08
# ...                                       ...
# former                           6.778742e-01
# four year ago                    8.421053e-01
# four year ago .                  3.684211e-01
# four-week                        5.789474e-01
# friday afternoon                 1.000000e+00
# higher-grade fuel four year ago  2.105263e-01
# in                               5.263158e-02
# july                             6.842105e-01
# july .                           2.631579e-01
# last june                        8.947368e-01
# month                            3.684211e-01
# morning                          5.263158e-01
# no_time                          2.472761e-01
# now                              5.607029e-01
# once                             3.684211e-01
# one second                       6.315789e-01
# over a week                      4.210526e-01
# second                           2.631579e-01
# seven year                       5.789474e-01
# seven year .                     2.631579e-01
# summer                           7.368421e-01
# the 20th century                 3.157895e-01
# the 26.2-mile event - set day    3.684211e-01
# the 99th day                     5.789474e-01
# the end of year                  5.789474e-01
# the next decade                  8.421053e-01
# the next decade .                3.157895e-01
# this year                        5.263158e-01
# year                             2.758621e-01
# year .                           2.105263e-01
#
# [92 rows x 3 columns]

# %% [markdown]
# ## Comparison with expert annotations

# %%
rows = []
header = list(results_closed["units"])
header.extend(["validated_time", "no_of_annotations", "validated_time_final_score", "validated_time_initial_score"])

rows.append(header)

for i in range(len(results_closed["units"].index)):
    keys = []
    all_event_runs = results_closed["units"]["input.all_runs_times"].iloc[i].lower().split("###")
    
    for event in all_event_runs:
        evComp = event.split("__")
        #print(evComp[0])
        keys.append(lemmatize_keywords(str(evComp[0]), " "))
    keys.append("no_time")
    #print(keys)
    for j in keys:

        row = list(results_closed["units"].iloc[i])
        row.append(j)
        
        row.append(results_closed["units"]["output.selectedtags_desc"].iloc[i][j.lower()])
        row.append(results_closed["units"]["unit_annotation_score"].iloc[i][j.lower()])
        row.append(results_closed["units"]["unit_annotation_score_initial"].iloc[i][j.lower()])
        rows.append(row)
        
import csv

with open('../pilot_data/' + file_name + '_units_closed.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(rows)

# %%
# expert annotations in TempEval-3 Platinum dataset
import numpy as np
           
expert_data = pd.read_csv("../TempEval3-data/TE3-Platinum_time.csv")
crowd_data = pd.read_csv("../pilot_data/" + file_name + "_units_closed.csv")
crowd_data["Experts"] = pd.Series(np.random.randn(len(crowd_data.index)), index=crowd_data.index)

for i in range(len(crowd_data.index)):
    subset = expert_data[(expert_data["Doc Id"].str.lower() == crowd_data["input.doc_id"].iloc[i].lower()) & (expert_data["Sentence Id"] == crowd_data["input.sentence_id"].iloc[i])]# & (str(str(expert_data["Lowercase Token"]) + "__" + str(expert_data["Start Offset"]) + "__" + str(expert_data["End Offset"])) == str(crowd_data["validated_event"].iloc[i]))]
    found = False
    for j in range(len(subset.index)):
        if str(subset["Lowercase Lemma Stanford"].iloc[j]) == crowd_data["validated_time"].iloc[i]:
            found = True
            break
    if found == True:
        crowd_data["Experts"].iloc[i] = 1
    else:
        crowd_data["Experts"].iloc[i] = 0
crowd_data.to_csv("../pilot_data/" + file_name + "_units_closed.csv", index=False)

# %%
import eval_crowd_results as eval_script

crowd = pd.read_csv('../pilot_data/' + file_name + '_units_closed.csv')
eval_file = eval_script.compute_crowd_performance(crowd, "validated_time_final_score")
     
with open('../pilot_data/eval_' + file_name + '_units_closed.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(eval_file)
    
eval_main = pd.read_csv("../pilot_data/eval_" + file_name + "_units_closed.csv")
eval_main
# Out:
#     Thresh  TP   TN  FP  FN  Precision    Recall  Accuracy  F1-score
# 0     0.05  56   42  66   0   0.459016  1.000000  0.597561  0.629213
# 1     0.10  56   48  60   0   0.482759  1.000000  0.634146  0.651163
# 2     0.15  56   48  60   0   0.482759  1.000000  0.634146  0.651163
# 3     0.20  56   50  58   0   0.491228  1.000000  0.646341  0.658824
# 4     0.25  56   52  56   0   0.500000  1.000000  0.658537  0.666667
# 5     0.30  56   56  52   0   0.518519  1.000000  0.682927  0.682927
# 6     0.35  56   61  47   0   0.543689  1.000000  0.713415  0.704403
# 7     0.40  54   70  38   2   0.586957  0.964286  0.756098  0.729730
# 8     0.45  52   78  30   4   0.634146  0.928571  0.792683  0.753623
# 9     0.50  49   83  25   7   0.662162  0.875000  0.804878  0.753846
# 10    0.55  47   85  23   9   0.671429  0.839286  0.804878  0.746032
# 11    0.60  47   91  17   9   0.734375  0.839286  0.841463  0.783333
# 12    0.65  43   94  14  13   0.754386  0.767857  0.835366  0.761062
# 13    0.70  38   95  13  18   0.745098  0.678571  0.810976  0.710280
# 14    0.75  35   97  11  21   0.760870  0.625000  0.804878  0.686275
# 15    0.80  30  101   7  26   0.810811  0.535714  0.798780  0.645161
# 16    0.85  28  102   6  28   0.823529  0.500000  0.792683  0.622222
# 17    0.90  23  102   6  33   0.793103  0.410714  0.762195  0.541176
# 18    0.95  15  103   5  41   0.750000  0.267857  0.719512  0.394737
# 19    1.00   7  107   1  49   0.875000  0.125000  0.695122  0.218750

# %% [markdown]
# ## Effect on CrowdTruth metrics
#
# Finally, we can compare the effect of the transformation from an open task to a closed task on the CrowdTruth *sentence quality score*.

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.scatter(
    results_open["units"]["uqs"],
    results_closed["units"]["uqs"],
)
plt.plot([0, 1], [0, 1], 'red', linewidth=1)
plt.title("Sentence Quality Score")
plt.xlabel("open task")
plt.ylabel("closed task")
# Out:
# Text(0,0.5,u'closed task')

# %%
plt.scatter(
    results_open["workers"]["wqs"],
    results_closed["workers"]["wqs"],
)
plt.plot([0, 1], [0, 1], 'red', linewidth=1)
plt.title("Worker Quality Score")
plt.xlabel("open task")
plt.ylabel("closed task")
# Out:
# Text(0,0.5,u'closed task')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

F1_3w = pd.read_csv("../scripts/F1_temporal_3.csv")
F1_4w = pd.read_csv("../scripts/F1_temporal_4.csv")
F1_5w = pd.read_csv("../scripts/F1_temporal_5.csv")
F1_6w = pd.read_csv("../scripts/F1_temporal_6.csv")
F1_7w = pd.read_csv("../scripts/F1_temporal_7.csv")
F1_8w = pd.read_csv("../scripts/F1_temporal_8.csv")
F1_9w = pd.read_csv("../scripts/F1_temporal_9.csv")
F1_10w = pd.read_csv("../scripts/F1_temporal_10.csv")
F1_11w = pd.read_csv("../scripts/F1_temporal_11.csv")
F1_12w = pd.read_csv("../scripts/F1_temporal_12.csv")
F1_13w = pd.read_csv("../scripts/F1_temporal_13.csv")
F1_14w = pd.read_csv("../scripts/F1_temporal_14.csv")
F1_15w = pd.read_csv("../scripts/F1_temporal_15.csv")
F1_16w = pd.read_csv("../scripts/F1_temporal_16.csv")
F1_17w = pd.read_csv("../scripts/F1_temporal_17.csv")
F1_18w = pd.read_csv("../scripts/F1_temporal_18.csv")
F1_19w = pd.read_csv("../scripts/F1_temporal_19.csv")
F1_20w = 0.803279


F1 = [F1_3w["f1"].mean(), F1_4w["f1"].mean(), F1_5w["f1"].mean(), F1_6w["f1"].mean(), F1_7w["f1"].mean(), 
      F1_8w["f1"].mean(), F1_9w["f1"].mean(), F1_10w["f1"].mean(), F1_11w["f1"].mean(), F1_12w["f1"].mean(), 
      F1_13w["f1"].mean(), F1_14w["f1"].mean(), F1_15w["f1"].mean(), F1_16w["f1"].mean(), F1_17w["f1"].mean(), 
      F1_18w["f1"].mean(), F1_19w["f1"].mean(), F1_20w]

std = [np.std(F1_3w["f1"]), np.std(F1_4w["f1"]), np.std(F1_5w["f1"]), np.std(F1_6w["f1"]), np.std(F1_7w["f1"]), 
      np.std(F1_8w["f1"]), np.std(F1_9w["f1"]), np.std(F1_10w["f1"]), np.std(F1_11w["f1"]), np.std(F1_12w["f1"]), 
      np.std(F1_13w["f1"]), np.std(F1_14w["f1"]), np.std(F1_15w["f1"]), np.std(F1_16w["f1"]), np.std(F1_17w["f1"]), 
      np.std(F1_18w["f1"]), np.std(F1_19w["f1"]), 0.0]

plt.rcParams['figure.figsize'] = 6, 4
plt.plot([x for x in range(3, 21)], F1, 'bo-',
         color = 'r', lw = 2, label = "F1 Crowd - Time Expressions")

plt.plot([x for x in range(3, 21)], std, 'bo-',
         color = 'blue', lw = 2, label = "Stdev Crowd - Time Expressions")

plt.xlabel("number of workers", fontsize=16)
plt.ylabel("F1-score", fontsize=16)
plt.xticks( range(3,21) , fontsize=16)
plt.ylim(0.0, 1.0)
leg = plt.legend(fontsize=10)
leg.get_frame().set_alpha(0.5)
plt.grid(ls=':')
plt.tight_layout()
plt.savefig("../pilot_data/temporal_no_of_workers.eps", format='eps', dpi=1000)
plt.show()
plt.close()
