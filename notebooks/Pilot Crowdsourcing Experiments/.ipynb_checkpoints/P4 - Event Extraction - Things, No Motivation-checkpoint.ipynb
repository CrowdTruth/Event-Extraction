# %% [markdown]
# # CrowdTruth for Sparse Multiple Choice Tasks: Event Extraction

# %%
import pandas as pd

file_name = "f1321547_things_nomotivation"
test_data = pd.read_csv("../../data/pilot_crowd_data/raw_data/" + file_name + ".csv")
test_data.head()
# Out:
#      _unit_id          _created_at         _id          _started_at  _tainted  \
# 0  2015652237  11/18/2018 08:19:50  4258989155  11/18/2018 08:19:23     False
# 1  2015652237  11/18/2018 08:44:21  4259017881  11/18/2018 08:44:05     False
# 2  2015652237  11/18/2018 11:33:00  4259214892  11/18/2018 11:32:38     False
# 3  2015652237  11/18/2018 15:29:56  4259580708  11/18/2018 15:29:39     False
# 4  2015652237  11/18/2018 15:42:49  4259605986  11/18/2018 15:41:43     False
#
#     _channel  _trust                        _worker_id _country _region  \
# 0  clixsense       1  623fdeab4ddd1aa6449bfd3e99c650df      GBR     NaN
# 1    wannads       1  017bbee01ff77eadfca65e4067b36da3      GBR      H7
# 2      elite       1  19d1cf4672a44a2b873901990979111a      USA      TX
# 3    prodege       1  d8d245c91422aa1ee8390a5faf482603      GBR      C9
# 4    instagc       1  1f2407ac6926cfdf579fa829a88c1d86      USA      AL
#
#     ...   events_count gold_total_events  hiddeninput_gold  \
# 0   ...            NaN                 6               NaN
# 1   ...            NaN                 6               NaN
# 2   ...            NaN                 6               NaN
# 3   ...            NaN                 6               NaN
# 4   ...            NaN                 6               NaN
#
#                                   lowercase_sentence original_sentence  \
# 0  former president nicolas sarkozy was informed ...               NaN
# 1  former president nicolas sarkozy was informed ...               NaN
# 2  former president nicolas sarkozy was informed ...               NaN
# 3  former president nicolas sarkozy was informed ...               NaN
# 4  former president nicolas sarkozy was informed ...               NaN
#
#    processed_sentence selectedtags_desc_gold  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
#
#                                             sentence sentence_id  tokens
# 0  Former President Nicolas Sarkozy was informed ...           0      47
# 1  Former President Nicolas Sarkozy was informed ...           0      47
# 2  Former President Nicolas Sarkozy was informed ...           0      47
# 3  Former President Nicolas Sarkozy was informed ...           0      47
# 4  Former President Nicolas Sarkozy was informed ...           0      47
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Declaring a pre-processing configuration
#
# The pre-processing configuration defines how to interpret the raw crowdsourcing input. To do this, we need to define a configuration class. First, we import the default CrowdTruth configuration class:

# %%
import crowdtruth
from crowdtruth.configuration import DefaultConfig

# %% [markdown]
# Our test class inherits the default configuration `DefaultConfig`, while also declaring some additional attributes that are specific to the Relation Extraction task:
#
# * **`inputColumns`:** list of input columns from the .csv file with the input data
# * **`outputColumns`:** list of output columns from the .csv file with the answers from the workers
# * **`annotation_separator`:** string that separates between the crowd annotations in `outputColumns`
# * **`open_ended_task`:** boolean variable defining whether the task is open-ended (i.e. the possible crowd annotations are not known beforehand, like in the case of free text input); in the task that we are processing, workers pick the answers from a pre-defined list, therefore the task is not open ended, and this variable is set to `False`
# * **`annotation_vector`:** list of possible crowd answers, mandatory to declare when `open_ended_task` is `False`; for our task, this is the list of all relations that were given as input to the crowd in at least one sentence
# * **`processJudgments`:** method that defines processing of the raw crowd data; for this task, we process the crowd answers to correspond to the values in `annotation_vector`
#
# The complete configuration class is declared below:

# %%
class TestConfig(DefaultConfig):
    inputColumns = ["doc_id", "total_events_gold", "sentence", "lowercase_sentence", "sentence_id", "all_runs_events"]
    outputColumns = ["selectedtags_desc"]
    
    annotation_separator = ","
        
    # processing of a closed task
    open_ended_task = True
    
    def processJudgments(self, judgments):
        # pre-process output to match the values in annotation_vector
        for col in self.outputColumns:
            # transform to lowercase
            judgments[col] = judgments[col].apply(lambda x: str(x).lower())
            # remove square brackets from annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('[',''))
            judgments[col] = judgments[col].apply(lambda x: str(x).replace(']',''))
            # remove the quotes around the annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('"',''))
        return judgments

# %% [markdown]
# ## Pre-processing the input data
#
# After declaring the configuration of our input file, we are ready to pre-process the crowd data:

# %%
data_open, config = crowdtruth.load(
    file = "../../data/pilot_crowd_data/raw_data/" + file_name + ".csv",
    config = TestConfig()
)

data_open['judgments'].head()
# Out:
#                                      output.selectedtags_desc  \
# judgment
# 4258989155   {'informed__37__45': 1, 'campaign__266__274': 1}
# 4259017881                            {'abused__113__119': 1}
# 4259214892     {'informed__37__45': 1, 'abused__113__119': 1}
# 4259580708  {'informed__37__45': 1, 'face__69__73': 1, 'in...
# 4259605986  {'informed__37__45': 1, 'face__69__73': 1, 'in...
#
#             output.selectedtags_desc.count  output.selectedtags_desc.unique  \
# judgment
# 4258989155                               2                                2
# 4259017881                               1                                1
# 4259214892                               2                                2
# 4259580708                               5                                5
# 4259605986                               4                                4
#
#                   unit                            worker             started  \
# judgment
# 4258989155  2015652237  623fdeab4ddd1aa6449bfd3e99c650df 2018-11-18 08:19:23
# 4259017881  2015652237  017bbee01ff77eadfca65e4067b36da3 2018-11-18 08:44:05
# 4259214892  2015652237  19d1cf4672a44a2b873901990979111a 2018-11-18 11:32:38
# 4259580708  2015652237  d8d245c91422aa1ee8390a5faf482603 2018-11-18 15:29:39
# 4259605986  2015652237  1f2407ac6926cfdf579fa829a88c1d86 2018-11-18 15:41:43
#
#                      submitted  duration  \
# judgment
# 4258989155 2018-11-18 08:19:50        27
# 4259017881 2018-11-18 08:44:21        16
# 4259214892 2018-11-18 11:33:00        22
# 4259580708 2018-11-18 15:29:56        17
# 4259605986 2018-11-18 15:42:49        66
#
#                                                           job
# judgment
# 4258989155  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 4259017881  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 4259214892  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 4259580708  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 4259605986  ../../data/pilot_crowd_data/raw_data/f1321547_...

# %% [markdown]
# ## Computing the CrowdTruth metrics
#
# The pre-processed data can then be used to calculate the CrowdTruth metrics:

# %%
results_open = crowdtruth.run(data_open, config)

# %% [markdown]
# `results` is a dict object that contains the quality metrics for sentences, events and crowd workers.
#
# The **sentence metrics** are stored in `results["units"]`:

# %%
results_open["units"].head()
# Out:
#             duration                              input.all_runs_events  \
# unit
# 2015652237     41.45  informed__37__45###face__69__73###investigatio...
# 2015652238     55.60  denied__16__22###accepting__23__32###alleged__...
# 2015652239     36.75  called__41__47###decision__61__69###indicates_...
# 2015652240     21.30   said__11__15###appeal__25__31###appeal .__25__33
# 2015652241     41.35  ruling__4__10###mean__32__36###lost__60__64###...
#
#                     input.doc_id  \
# unit
# 2015652237  nyt_20130321_sarkozy
# 2015652238  nyt_20130321_sarkozy
# 2015652239  nyt_20130321_sarkozy
# 2015652240  nyt_20130321_sarkozy
# 2015652241  nyt_20130321_sarkozy
#
#                                      input.lowercase_sentence  \
# unit
# 2015652237  former president nicolas sarkozy was informed ...
# 2015652238  mr. sarkozy has denied accepting illegal campa...
# 2015652239  mr. sarkozy s lawyer , thierry herzog , called...
# 2015652240                  the lawyer said he would appeal 0
# 2015652241  the ruling does not necessarily mean that mr. ...
#
#                                                input.sentence  \
# unit
# 2015652237  Former President Nicolas Sarkozy was informed ...
# 2015652238  Mr. Sarkozy has denied accepting illegal campa...
# 2015652239  Mr. Sarkozy 's lawyer , Thierry Herzog , calle...
# 2015652240                  The lawyer said he would appeal .
# 2015652241  The ruling does not necessarily mean that Mr. ...
#
#             input.sentence_id  \
# unit
# 2015652237                  0
# 2015652238                  1
# 2015652239                  2
# 2015652240                  3
# 2015652241                  4
#
#                                                           job  \
# unit
# 2015652237  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 2015652238  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 2015652239  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 2015652240  ../../data/pilot_crowd_data/raw_data/f1321547_...
# 2015652241  ../../data/pilot_crowd_data/raw_data/f1321547_...
#
#                                      output.selectedtags_desc  \
# unit
# 2015652237  {'informed__37__45': 17, 'campaign__266__274':...
# 2015652238  {'denied accepting__16__32': 11, 'campaign__41...
# 2015652239  {'called__41__47': 14, 'indicates__78__87': 11...
# 2015652240  {'said__11__15': 16, 'appeal__25__31': 15, 'ap...
# 2015652241  {'stand__156__161': 12, 'lost__60__64': 14, 'r...
#
#             output.selectedtags_desc.annotations  \
# unit
# 2015652237                                    76
# 2015652238                                    46
# 2015652239                                    70
# 2015652240                                    37
# 2015652241                                    60
#
#             output.selectedtags_desc.unique_annotations  worker       uqs  \
# unit
# 2015652237                                            6      20  0.668743
# 2015652238                                            5      20  0.489715
# 2015652239                                            6      20  0.600058
# 2015652240                                            3      20  0.700588
# 2015652241                                            6      20  0.596438
#
#                                         unit_annotation_score  uqs_initial  \
# unit
# 2015652237  {'informed__37__45': 0.8946067038350854, 'camp...     0.625944
# 2015652238  {'denied accepting__16__32': 0.557251894143286...     0.444478
# 2015652239  {'called__41__47': 0.7857993383346975, 'indica...     0.541097
# 2015652240  {'said__11__15': 0.8295543011824428, 'appeal__...     0.676423
# 2015652241  {'stand__156__161': 0.5873619548516986, 'lost_...     0.563330
#
#                                 unit_annotation_score_initial
# unit
# 2015652237  {'informed__37__45': 0.85, 'campaign__266__274...
# 2015652238  {'denied accepting__16__32': 0.55, 'campaign__...
# 2015652239  {'called__41__47': 0.7, 'indicates__78__87': 0...
# 2015652240  {'said__11__15': 0.8, 'appeal__25__31': 0.75, ...
# 2015652241  {'stand__156__161': 0.6, 'lost__60__64': 0.7, ...

# %% [markdown]
# The `uqs` column in `results["units"]` contains the **sentence quality scores**, capturing the overall workers agreement over each sentence. Here we plot its histogram:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(results_open["units"]["uqs"])
plt.xlabel("Sentence Quality Score")
plt.ylabel("Sentences")

# %% [markdown]
# The `unit_annotation_score` column in `results["units"]` contains the **sentence-relation scores**, capturing the likelihood that a relation is expressed in a sentence. For each sentence, we store a dictionary mapping each relation to its sentence-relation score.

# %%
results_open["units"]["unit_annotation_score"].head(10)
# Out:
# unit
# 2015652237    {'informed__37__45': 0.8946067038350854, 'camp...
# 2015652238    {'denied accepting__16__32': 0.557251894143286...
# 2015652239    {'called__41__47': 0.7857993383346975, 'indica...
# 2015652240    {'said__11__15': 0.8295543011824428, 'appeal__...
# 2015652241    {'stand__156__161': 0.5873619548516986, 'lost_...
# 2015652242    {'accused__23__30': 0.8997926608884879, 'fakin...
# 2015652243    {'reported__57__65': 0.9174439524523865, 'miss...
# 2015652244    {'search__31__37': 0.7865522808128919, 'said__...
# 2015652245    {'pulled__32__38': 0.819355852437829, 'showed_...
# 2015652246    {'said__139__143': 0.7195814733899851, 'wanted...
# Name: unit_annotation_score, dtype: object

# %% [markdown]
# The **worker metrics** are stored in `results["workers"]`:

# %%
results_open["workers"].head()
# Out:
#                                   unit  judgment  job    duration       wqs  \
# worker
# 017bbee01ff77eadfca65e4067b36da3    50        50    1   16.080000  0.308935
# 07fe811ad57531a29d0ce82daedb4ad7    44        44    1  169.727273  0.469287
# 0d9bdc31b5837ca4dbf0a99ba7add9b5     3         3    1   46.333333  0.418243
# 19d1cf4672a44a2b873901990979111a    50        50    1   27.780000  0.435904
# 1f2407ac6926cfdf579fa829a88c1d86    50        50    1   71.660000  0.638035
#
#                                        wwa       wsa  wqs_initial  \
# worker
# 017bbee01ff77eadfca65e4067b36da3  0.522193  0.591610     0.275125
# 07fe811ad57531a29d0ce82daedb4ad7  0.634527  0.739585     0.428640
# 0d9bdc31b5837ca4dbf0a99ba7add9b5  0.568113  0.736197     0.395556
# 19d1cf4672a44a2b873901990979111a  0.615470  0.708246     0.401535
# 1f2407ac6926cfdf579fa829a88c1d86  0.743546  0.858097     0.592079
#
#                                   wwa_initial  wsa_initial
# worker
# 017bbee01ff77eadfca65e4067b36da3     0.484723     0.567592
# 07fe811ad57531a29d0ce82daedb4ad7     0.593352     0.722405
# 0d9bdc31b5837ca4dbf0a99ba7add9b5     0.538534     0.734505
# 19d1cf4672a44a2b873901990979111a     0.579911     0.692409
# 1f2407ac6926cfdf579fa829a88c1d86     0.700653     0.845039

# %% [markdown]
# The `wqs` columns in `results["workers"]` contains the **worker quality scores**, capturing the overall agreement between one worker and all the other workers.

# %%
plt.hist(results_open["workers"]["wqs"])
plt.xlabel("Worker Quality Score")
plt.ylabel("Workers")

# %% [markdown]
# ## Save crowd results in a csv file

# %%
rows = []
header = list(results_open["units"])
header.extend(["validated_event", "no_of_annotations", "validated_event_final_score", "validated_event_initial_score"])

rows.append(header)

for i in range(len(results_open["units"].index)):
    keys = []
    all_event_runs = results_open["units"]["input.all_runs_events"].iloc[i].lower().split("###")
    keys.extend(all_event_runs)
    keys.append("no_event")
    
    for j in range(len(keys)):
        row = list(results_open["units"].iloc[i])
        row.append(keys[j])
        row.append(results_open["units"]["output.selectedtags_desc"].iloc[i][keys[j].lower()])
        row.append(results_open["units"]["unit_annotation_score"].iloc[i][keys[j].lower()])
        row.append(results_open["units"]["unit_annotation_score_initial"].iloc[i][keys[j].lower()])
    
        rows.append(row)
        
        
import csv

with open('../../data/pilot_crowd_data/results/' + file_name + '_units_open.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(rows)

# %% [markdown]
# ## Comparison with Expert Annotations

# %%
# expert annotations in TempEval-3 Platinum dataset
import numpy as np
           
expert_data = pd.read_csv("../../data/TempEval3-data/TE3-Platinum_events.csv")
crowd_data = pd.read_csv("../../data/pilot_crowd_data/results/"+ file_name + "_units_open.csv")
crowd_data["Experts"] = pd.Series(np.random.randn(len(crowd_data.index)), index=crowd_data.index)

for i in range(len(crowd_data.index)):
    subset = expert_data[(expert_data["Doc Id"].str.lower() == crowd_data["input.doc_id"].iloc[i].lower()) & (expert_data["Sentence Id"] == crowd_data["input.sentence_id"].iloc[i])]# & (str(str(expert_data["Lowercase Token"]) + "__" + str(expert_data["Start Offset"]) + "__" + str(expert_data["End Offset"])) == str(crowd_data["validated_event"].iloc[i]))]
    found = False
    for j in range(len(subset.index)):
        if str(str(subset["Lowercase Token"].iloc[j]) + "__" + str(subset["Start Offset"].iloc[j]) + "__" + str(subset["End Offset"].iloc[j])) == crowd_data["validated_event"].iloc[i]:
            found = True
    if found == True:
        crowd_data["Experts"].iloc[i] = 1
    else:
        crowd_data["Experts"].iloc[i] = 0
crowd_data.to_csv("../../data/pilot_crowd_data/results/" + file_name + "_units_open.csv", index=False)
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import eval_crowd_results as eval_script
import pandas as pd
import csv
crowd = pd.read_csv('../pilot_data/' + file_name + '_units_open.csv')
eval_file = eval_script.compute_crowd_performance(crowd, "validated_event_final_score")
     
with open('../pilot_data/eval_' + file_name + '_units_open.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(eval_file)
    
eval_main = pd.read_csv("../pilot_data/eval_" + file_name + "_units_open.csv")
eval_main
# Out:
#     Thresh   TP  TN  FP   FN  Precision    Recall  Accuracy  F1-score
# 0     0.05  162  48  51    0   0.760563  1.000000  0.804598  0.864000
# 1     0.10  161  51  48    1   0.770335  0.993827  0.812261  0.867925
# 2     0.15  161  53  46    1   0.777778  0.993827  0.819923  0.872629
# 3     0.20  158  56  43    4   0.786070  0.975309  0.819923  0.870523
# 4     0.25  158  59  40    4   0.797980  0.975309  0.831418  0.877778
# 5     0.30  158  62  37    4   0.810256  0.975309  0.842912  0.885154
# 6     0.35  157  66  33    5   0.826316  0.969136  0.854406  0.892045
# 7     0.40  153  71  28    9   0.845304  0.944444  0.858238  0.892128
# 8     0.45  145  75  24   17   0.857988  0.895062  0.842912  0.876133
# 9     0.50  137  77  22   25   0.861635  0.845679  0.819923  0.853583
# 10    0.55  126  79  20   36   0.863014  0.777778  0.785441  0.818182
# 11    0.60  117  87  12   45   0.906977  0.722222  0.781609  0.804124
# 12    0.65  101  90   9   61   0.918182  0.623457  0.731801  0.742647
# 13    0.70   91  92   7   71   0.928571  0.561728  0.701149  0.700000
# 14    0.75   81  95   4   81   0.952941  0.500000  0.674330  0.655870
# 15    0.80   59  98   1  103   0.983333  0.364198  0.601533  0.531532
# 16    0.85   37  99   0  125   1.000000  0.228395  0.521073  0.371859
# 17    0.90   19  99   0  143   1.000000  0.117284  0.452107  0.209945
# 18    0.95    7  99   0  155   1.000000  0.043210  0.406130  0.082840
# 19    1.00    4  99   0  158   1.000000  0.024691  0.394636  0.048193

# %% [markdown]
# ## Open to Closed Task Transformation
#
# The goal of this crowdsourcing task is to understand how clearly a word or a word phrase is expressing an event or an action across all the sentences in the dataset and not at the level of a single sentence as previously. Therefore, in the remainder of this tutorial we show how to *translate an open task to a closed task* by processing *both the input units and the annotations* of a crowdsourcing task.
#
# The answers from the crowd are stored in the `selected_events` column.

# %%
test_data["selectedtags_desc"][0:30]
# Out:
# 0             ["informed__37__45","campaign__266__274"]
# 1                                  ["abused__113__119"]
# 2               ["informed__37__45","abused__113__119"]
# 3     ["informed__37__45","face__69__73","investigat...
# 4     ["informed__37__45","face__69__73","investigat...
# 5     ["informed__37__45","investigation__83__96","a...
# 6     ["informed__37__45","face__69__73","investigat...
# 7     ["informed__37__45","face__69__73","abused__11...
# 8     ["informed__37__45","face__69__73","investigat...
# 9     ["informed__37__45","face__69__73","investigat...
# 10    ["informed__37__45","investigation__83__96","c...
# 11    ["informed__37__45","investigation__83__96","a...
# 12       ["investigation__83__96","campaign__266__274"]
# 13    ["informed__37__45","investigation__83__96","a...
# 14    ["informed__37__45","face__69__73","investigat...
# 15    ["face__69__73","abused__113__119","get__230__...
# 16    ["informed__37__45","face__69__73","get__230__...
# 17    ["informed__37__45","face__69__73","investigat...
# 18    ["informed__37__45","face__69__73","investigat...
# 19              ["informed__37__45","abused__113__119"]
# 20                         ["denied accepting__16__32"]
# 21                                 ["campaign__41__49"]
# 22    ["denied__16__22","accepting__23__32","alleged...
# 23     ["alleged__159__166","denied accepting__16__32"]
# 24    ["denied__16__22","accepting__23__32","alleged...
# 25    ["denied__16__22","accepting__23__32","alleged...
# 26     ["alleged__159__166","denied accepting__16__32"]
# 27    ["denied__16__22","accepting__23__32","alleged...
# 28               ["denied__16__22","accepting__23__32"]
# 29               ["denied__16__22","alleged__159__166"]
# Name: selectedtags_desc, dtype: object

# %% [markdown]
# As you already know, each word can be expressed in a canonical form, i.e., as a lemma. For example, the words: *run*, *runs*, *running*, they all have the lemma *run*. As you can see in the previous cell, events in text can appear under multiple forms. To evaluate the clarity of each event, we will process both the input units and the crowd annotations to refer to a word in its canonical form, i.e., we will lemmatize them.

# %% [markdown]
# Following, we define the function used to lemmatize the options that are shown to the workers in the crowdsourcing task:

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

def nltk2wn_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None
    
def lemmatize_events(event):
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(str(event.lower().split("__")[0])))  
    wn_tagged = map(lambda x: (str(x[0]), nltk2wn_tag(x[1])), nltk_tagged)
    res_words = []
                
    for word, tag in wn_tagged:
        if tag is None:            
            res_word = wordnet._morphy(str(word), wordnet.NOUN)
            if res_word == []:
                res_words.append(str(word))
            else:
                if len(res_word) == 1:
                    res_words.append(str(res_word[0]))
                else:
                    res_words.append(str(res_word[1]))
        else:
            res_word = wordnet._morphy(str(word), tag)
            if res_word == []:
                res_words.append(str(word))
            else: 
                if len(res_word) == 1:
                    res_words.append(str(res_word[0]))
                else:
                    res_words.append(str(res_word[1]))
    
    lematized_keyword = " ".join(res_words)
    return lematized_keyword
# Out:
# [nltk_data] Downloading package punkt to /Users/oanainel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

def nltk2wn_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None
# Out:
# [nltk_data] Downloading package punkt to /Users/oanainel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/oanainel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# The following functions create the values of the annotation vector and extracts the lemma of the events selected by each worker.

# %%
def define_annotation_vector(eventsList):  
    events = []
    for i in range(len(eventsList)):
        currentEvents = eventsList[i].split("###")
        
        for j in range(len(currentEvents)):
            if currentEvents[j] == ",":
                events.append(",")
            elif currentEvents[j] != "no_event":
                lematized_keyword = lemmatize_events(currentEvents[j])
                
                if lematized_keyword not in events:
                    events.append(lematized_keyword)
    events.append("no_event")   
    return events

def lemmatize_keywords(keywords, separator):
    keywords_list = keywords.split(separator)
    lematized_keywords = []
    
    for keyword in keywords_list:
        lematized_keyword = lemmatize_events(keyword)
        lematized_keywords.append(lematized_keyword)
    
    return separator.join(lematized_keywords)

# %%
class TestConfig(DefaultConfig):
    inputColumns = ["doc_id", "total_events_gold", "sentence", "lowercase_sentence", "sentence_id", "all_runs_events"]
    outputColumns = ["selectedtags_desc"]
    
    annotation_separator = ","
        
    # processing of a closed task
    open_ended_task = False
    annotation_vector = define_annotation_vector(test_data["all_runs_events"])
    
    def processJudgments(self, judgments):
        # pre-process output to match the values in annotation_vector
        for col in self.outputColumns:
            # transform to lowercase
            judgments[col] = judgments[col].apply(lambda x: str(x).lower())
            # remove square brackets from annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace("[",""))
            judgments[col] = judgments[col].apply(lambda x: str(x).replace("]",""))
            # remove the quotes around the annotations
            judgments[col] = judgments[col].apply(lambda x: str(x).replace('"',''))
            judgments[col] = judgments[col].apply(lambda x: lemmatize_keywords(str(x), self.annotation_separator))
        return judgments

# %%
data_closed, config = crowdtruth.load(
    file = "../pilot_data/" + file_name + ".csv",
    config = TestConfig()
)

data_closed['judgments'].head()
# Out:
# judgment
# 4258989155    {u'inform': 1, u'campaign': 1, u'face': 0, u'i...
# 4259017881    {u'abuse': 1, u'inform': 0, u'face': 0, u'inve...
# 4259214892    {u'inform': 1, u'abuse': 1, u'face': 0, u'inve...
# 4259580708    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4259605986    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4259644345    {u'inform': 1, u'investigation': 1, u'abuse': ...
# 4259764581    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4259790743    {u'inform': 1, u'face': 1, u'abuse': 1, u'get'...
# 4259853855    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4259934563    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4260049024    {u'inform': 1, u'investigation': 1, u'campaign...
# 4260139829    {u'inform': 1, u'investigation': 1, u'abuse': ...
# 4260151355    {u'investigation': 1, u'campaign': 1, u'inform...
# 4260307659    {u'inform': 1, u'investigation': 1, u'abuse': ...
# 4260331895    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4260333577    {u'face': 1, u'abuse': 1, u'get': 1, u'inform'...
# 4260342960    {u'inform': 1, u'face': 1, u'get': 1, u'invest...
# 4260396145    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4260397420    {u'inform': 1, u'face': 1, u'investigation': 1...
# 4260406188    {u'inform': 1, u'abuse': 1, u'face': 0, u'inve...
# 4259022894    {u'deny accept': 1, u'inform': 0, u'face': 0, ...
# 4259228793    {u'campaign': 1, u'inform': 0, u'face': 0, u'i...
# 4259594817    {u'deny': 1, u'accept': 1, u'allege': 1, u'den...
# 4259636541    {u'allege': 1, u'deny accept': 1, u'inform': 0...
# 4259653985    {u'deny': 1, u'accept': 1, u'allege': 1, u'den...
# 4259784992    {u'deny': 1, u'accept': 1, u'allege': 1, u'cam...
# 4259799561    {u'allege': 1, u'deny accept': 1, u'inform': 0...
# 4259858348    {u'deny': 1, u'accept': 1, u'allege': 1, u'cam...
# 4259954580    {u'deny': 1, u'accept': 1, u'inform': 0, u'fac...
# 4260066736    {u'deny': 1, u'allege': 1, u'inform': 0, u'fac...
#                                     ...
# 4260237021    {u'affected': 1, u'blow': 1, u'inform': 0, u'f...
# 4260327259    {u'blow': 1, u'add': 1, u'inform': 0, u'face':...
# 4260344540    {u'be': 1, u'add': 1, u'inform': 0, u'face': 0...
# 4260405923    {u'affected': 1, u'blow': 1, u'add': 1, u'info...
# 4260420259    {u'affected': 1, u'add': 1, u'inform': 0, u'fa...
# 4260437133    {u'blow': 1, u'add': 1, u'inform': 0, u'face':...
# 4260439313    {u'affected': 1, u'blow': 1, u'inform': 0, u'f...
# 4260452287    {u'affected': 1, u'add': 1, u'inform': 0, u'fa...
# 4260454273    {u'drift': 1, u'inform': 0, u'face': 0, u'inve...
# 4260503519    {u'affected': 1, u'blow': 1, u'drift': 1, u'in...
# 4258978452    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259010337    {u'wind': 1, u'inform': 0, u'face': 0, u'inves...
# 4259200485    {u'kill': 1, u'inform': 0, u'face': 0, u'inves...
# 4259200575    {u'kill': 1, u'inform': 0, u'face': 0, u'inves...
# 4259211957    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259238352    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259499683    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259511248    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259547737    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259562387    {u'kill': 1, u'inform': 0, u'face': 0, u'inves...
# 4259621144    {u'kill': 1, u'inform': 0, u'face': 0, u'inves...
# 4259662427    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259732627    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259749658    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259777263    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259833541    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259846499    {u'season': 1, u'kill': 1, u'wind': 1, u'infor...
# 4259916970    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259921804    {u'kill': 1, u'wind': 1, u'inform': 0, u'face'...
# 4259947746    {u'kill': 1, u'inform': 0, u'face': 0, u'inves...
# Name: output.selectedtags_desc, Length: 1000, dtype: object

# %%
results_closed = crowdtruth.run(data_closed, config)

# %%
results_closed["annotations"]
# Out:
#              output.selectedtags_desc           aqs   aqs_initial
# ,                                1000  1.000000e-08  1.000000e-08
# abuse                            1000  6.760255e-01  6.153846e-01
# accept                           1000  3.299995e-01  2.631579e-01
# accepted                         1000  1.000000e+00  1.000000e+00
# accessible                       1000  4.652372e-01  4.210526e-01
# accuse                           1000  8.981388e-01  8.421053e-01
# add                              1000  7.169325e-01  6.858639e-01
# admit                            1000  1.000000e+00  1.000000e+00
# affect                           1000  7.876851e-01  7.368421e-01
# affected                         1000  7.846461e-01  7.438776e-01
# affordable                       1000  4.736826e-01  4.210526e-01
# agree                            1000  7.667311e-01  7.163212e-01
# agreement                        1000  7.499480e-01  6.842105e-01
# allege                           1000  6.616552e-01  5.789474e-01
# analysis                         1000  4.849490e-01  4.210526e-01
# announce                         1000  9.304929e-01  8.947368e-01
# appeal                           1000  7.560777e-01  7.368421e-01
# appeal .                         1000  2.604362e-01  2.631579e-01
# appear                           1000  5.306603e-01  4.736842e-01
# arrest                           1000  8.171254e-01  7.430876e-01
# ask                              1000  8.777187e-01  8.421053e-01
# be                               1000  1.165809e-01  1.052632e-01
# believe                          1000  5.225329e-01  4.736842e-01
# bid                              1000  3.709875e-01  3.157895e-01
# blackout                         1000  8.686434e-01  8.421053e-01
# block                            1000  8.582727e-01  8.421053e-01
# blow                             1000  6.914003e-01  6.315789e-01
# bring                            1000  4.532344e-01  4.210526e-01
# bring flood                      1000  5.083431e-01  4.736842e-01
# buying                           1000  8.149457e-01  7.368421e-01
# ...                               ...           ...           ...
# season                           1000  2.909646e-01  2.631579e-01
# see                              1000  6.900344e-01  6.315789e-01
# sell                             1000  4.934343e-01  4.736842e-01
# sentence                         1000  6.357635e-01  5.789474e-01
# session                          1000  5.254815e-01  4.736842e-01
# set                              1000  9.250819e-01  8.684211e-01
# show                             1000  9.028587e-01  8.421053e-01
# snow                             1000  5.420220e-01  4.918033e-01
# speed                            1000  8.154820e-01  7.894737e-01
# stand                            1000  5.622665e-01  5.789474e-01
# start                            1000  7.250274e-01  7.026144e-01
# stem                             1000  7.545455e-01  7.368421e-01
# straighten                       1000  8.191885e-01  7.894737e-01
# suggests                         1000  7.748477e-01  7.368421e-01
# talk                             1000  5.712653e-01  5.263158e-01
# thought                          1000  5.890718e-01  5.263158e-01
# tie                              1000  4.140490e-01  3.684211e-01
# time                             1000  1.319771e-01  1.052632e-01
# told                             1000  7.237887e-01  6.501458e-01
# transport                        1000  2.515136e-01  2.105263e-01
# trap                             1000  8.607545e-01  7.894737e-01
# treatment                        1000  8.304539e-01  7.894737e-01
# trial                            1000  5.965554e-01  5.789474e-01
# unaware                          1000  3.165265e-01  2.631579e-01
# uncovered                        1000  8.944435e-01  8.947368e-01
# vary                             1000  3.813879e-01  3.684211e-01
# want                             1000  8.767934e-01  8.421053e-01
# warn                             1000  8.137620e-01  7.368421e-01
# wind                             1000  7.808257e-01  7.368421e-01
# write                            1000  9.030630e-01  8.421053e-01
#
# [157 rows x 3 columns]

# %% [markdown]
# ## Comparison with expert annotations

# %%
rows = []
header = list(results_closed["units"])
header.extend(["validated_event", "no_of_annotations", "validated_event_final_score", "validated_event_initial_score"])

rows.append(header)

for i in range(len(results_closed["units"].index)):
    keys = []
    all_event_runs = results_closed["units"]["input.all_runs_events"].iloc[i].lower().split("###")
    
    for event in all_event_runs:
        evComp = event.split("__")
        #print(evComp[0])
        keys.append(lemmatize_keywords(str(evComp[0]), " "))
    keys.append("no_event")
    #print(keys)
    for j in keys:

        row = list(results_closed["units"].iloc[i])
        row.append(j)
        
        row.append(results_closed["units"]["output.selectedtags_desc"].iloc[i][j.lower()])
        row.append(results_closed["units"]["unit_annotation_score"].iloc[i][j.lower()])
        row.append(results_closed["units"]["unit_annotation_score_initial"].iloc[i][j.lower()])
        rows.append(row)
        
import csv

with open('../pilot_data/' + file_name + '_units_closed.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(rows)

# %%
# expert annotations in TempEval-3 Platinum dataset
import numpy as np
           
expert_data = pd.read_csv("../TempEval3-data/TE3-Platinum_events.csv")
crowd_data = pd.read_csv("../pilot_data/" + file_name + "_units_closed.csv")
crowd_data["Experts"] = pd.Series(np.random.randn(len(crowd_data.index)), index=crowd_data.index)

for i in range(len(crowd_data.index)):
    subset = expert_data[(expert_data["Doc Id"].str.lower() == crowd_data["input.doc_id"].iloc[i].lower()) & (expert_data["Sentence Id"] == crowd_data["input.sentence_id"].iloc[i])]# & (str(str(expert_data["Lowercase Token"]) + "__" + str(expert_data["Start Offset"]) + "__" + str(expert_data["End Offset"])) == str(crowd_data["validated_event"].iloc[i]))]
    found = False
    for j in range(len(subset.index)):
        if str(subset["Lowercase Lemma Stanford"].iloc[j]) == crowd_data["validated_event"].iloc[i]:
            found = True
    if found == True:
        crowd_data["Experts"].iloc[i] = 1
    else:
        crowd_data["Experts"].iloc[i] = 0
crowd_data.to_csv("../pilot_data/" + file_name + "_units_closed.csv", index=False)

# %%
import eval_crowd_results as eval_script

crowd = pd.read_csv('../pilot_data/' + file_name + '_units_closed.csv')
eval_file = eval_script.compute_crowd_performance(crowd, "validated_event_final_score")
     
with open('../pilot_data/eval_' + file_name + '_units_closed.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(eval_file)
    
eval_main = pd.read_csv("../pilot_data/eval_" + file_name + "_units_closed.csv")
eval_main
# Out:
#     Thresh   TP   TN  FP   FN  Precision    Recall  Accuracy  F1-score
# 0     0.05  151   48  62    0   0.708920  1.000000  0.762452  0.829670
# 1     0.10  150   51  59    1   0.717703  0.993377  0.770115  0.833333
# 2     0.15  150   53  57    1   0.724638  0.993377  0.777778  0.837989
# 3     0.20  147   56  54    4   0.731343  0.973510  0.777778  0.835227
# 4     0.25  147   59  51    4   0.742424  0.973510  0.789272  0.842407
# 5     0.30  147   63  47    4   0.757732  0.973510  0.804598  0.852174
# 6     0.35  146   66  44    5   0.768421  0.966887  0.812261  0.856305
# 7     0.40  143   71  39    8   0.785714  0.947020  0.819923  0.858859
# 8     0.45  136   74  36   15   0.790698  0.900662  0.804598  0.842105
# 9     0.50  127   75  35   24   0.783951  0.841060  0.773946  0.811502
# 10    0.55  117   77  33   34   0.780000  0.774834  0.743295  0.777409
# 11    0.60  107   85  25   44   0.810606  0.708609  0.735632  0.756184
# 12    0.65   95   89  21   56   0.818966  0.629139  0.704981  0.711610
# 13    0.70   85   92  18   66   0.825243  0.562914  0.678161  0.669291
# 14    0.75   73   93  17   78   0.811111  0.483444  0.636015  0.605809
# 15    0.80   55  100  10   96   0.846154  0.364238  0.593870  0.509259
# 16    0.85   36  105   5  115   0.878049  0.238411  0.540230  0.375000
# 17    0.90   22  107   3  129   0.880000  0.145695  0.494253  0.250000
# 18    0.95    9  108   2  142   0.818182  0.059603  0.448276  0.111111
# 19    1.00    4  108   2  147   0.666667  0.026490  0.429119  0.050955

# %% [markdown]
# ## Effect on CrowdTruth metrics
#
# Finally, we can compare the effect of the transformation from an open task to a closed task on the CrowdTruth *sentence quality score*.

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.scatter(
    results_open["units"]["uqs"],
    results_closed["units"]["uqs"],
)
plt.plot([0, 1], [0, 1], 'red', linewidth=1)
plt.title("Sentence Quality Score")
plt.xlabel("open task")
plt.ylabel("closed task")
# Out:
# Text(0,0.5,u'closed task')

# %%
plt.scatter(
    results_open["workers"]["wqs"],
    results_closed["workers"]["wqs"],
)
plt.plot([0, 1], [0, 1], 'red', linewidth=1)
plt.title("Worker Quality Score")
plt.xlabel("open task")
plt.ylabel("closed task")
# Out:
# Text(0,0.5,u'closed task')
