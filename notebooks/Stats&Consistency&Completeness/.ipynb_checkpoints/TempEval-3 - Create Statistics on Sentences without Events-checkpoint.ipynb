# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import string
import csv
# %matplotlib inline

# %%
sentences = pd.read_csv("../../data/TempEval3-data/TE3-Platinum_sentences.csv")
subsetSentences = sentences[sentences['#Events'] == 0]

tokens = pd.read_csv("../../data/TempEval3-data/TE3-Platinum_tokens.csv", skip_blank_lines=True)
subsetTokens = pd.DataFrame()

for i in range(len(subsetSentences.index)):
    subset = tokens[(tokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (tokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    frames = [subsetTokens, subset]
    subsetTokens = pd.concat(frames)

# %%
subsetTokens.head(5)
# Out:
#           Doc Id  Sentence Id  Token Id Doc  Token Id Sent       Token  \
# 226  AP_20130322           10           227              1         The
# 227  AP_20130322           10           228              2  government
# 228  AP_20130322           10           229              3        only
# 229  AP_20130322           10           230              4        does
# 230  AP_20130322           10           231              5           a
#
#     Lowercase Token  Start Offset  End Offset  Is Event Event Id  \
# 226             the             0           3         0        O
# 227      government             4          14         0        O
# 228            only            15          19         0        O
# 229            does            20          24         0        O
# 230               a            25          26         0        O
#
#          ...       POS Tag Stanford Lemma Stanford Lowercase Lemma Stanford  \
# 226      ...                     DT            the                      the
# 227      ...                     NN     government               government
# 228      ...                     RB           only                     only
# 229      ...                    VBZ             do                       do
# 230      ...                     DT              a                        a
#
#     POS Tag Is Time Expression Time Expression Id Time Expression Type  \
# 226      DT                  0                  O                    O
# 227      NN                  0                  O                    O
# 228      RB                  0                  O                    O
# 229      VB                  0                  O                    O
# 230      DT                  0                  O                    O
#
#     Time Expression Value      Token POS      Lemma POS
# 226                     O         the-DT         the-DT
# 227                     O  government-NN  government-NN
# 228                     O        only-RB        only-RB
# 229                     O        does-VB          do-VB
# 230                     O           a-DT           a-DT
#
# [5 rows x 25 columns]

# %%
sum(subsetSentences['#Tokens'])
# Out:
# 535

# %%
sLength = len(subsetSentences['Doc Id'])
subsetSentences['# POS Tags VB'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        if ('VB' in subset['POS Tag'].iloc[j]):
            count = count + 1
    
    subsetSentences['# POS Tags VB'].iloc[i] = int(count)
# Out:
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/oanainel/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
subsetSentences.head(5)
# Out:
#                         Doc Id  Sentence Id  \
# 59                 AP_20130322           10
# 62                 AP_20130322           13
# 78         nyt_20130321_cyprus           12
# 108  nyt_20130321_women_senate            5
# 111  nyt_20130321_women_senate            8
#
#                                               Sentence  \
# 59   The government only does a national flu death ...
# 62   That 's more than 2 1/2 times higher than any ...
# 78   That is a mere rounding error compared with th...
# 108   `` There still just are n't that many of us . ''
# 111  A record nine women now lead committees , incl...
#
#                                     Lowercase Sentence  #Tokens  \
# 59   the government only does a national flu death ...       12
# 62   that 's more than 2 1/2 times higher than any ...       13
# 78   that is a mere rounding error compared with th...       17
# 108   `` there still just are n't that many of us . ''       12
# 111  a record nine women now lead committees , incl...       16
#
#                                       Stanford POS Tag  \
# 59                DT NN RB VBZ DT JJ NN NN NN IN NNS .
# 62           DT VBZ JJR IN CD NNS JJR IN DT JJ JJ NN .
# 78   DT VBZ DT JJ VBG NN VBN IN DT NN NN NN IN CD C...
# 108               `` EX RB RB VBP RB IN JJ IN PRP . ''
# 111  DT NN CD NNS RB VBP NNS , VBG DT IN DT RBS JJ ...
#
#                                         Stanford Lemma  \
# 59   the government only do a national flu death co...
# 62   that be more than 2 1/2 time higher than any o...
# 78   that be a mere round error compare with the eu...
# 108    `` there still just be not that many of we . ''
# 111  a record nine woman now lead committee , inclu...
#
#                                   Stanford Lower Lemma  #POS Tags  #Lemmas  \
# 59   the government only do a national flu death co...         12       12
# 62   that be more than 2 1/2 time higher than any o...         13       13
# 78   that be a mere round error compare with the eu...         17       17
# 108    `` there still just be not that many of we . ''         12       12
# 111  a record nine woman now lead committee , inclu...         16       16
#
#      #Events  #Time Expressions  \
# 59         0                  0
# 62         0                  1
# 78         0                  0
# 108        0                  0
# 111        0                  1
#
#                                         All Runs Times  # POS Tags VB
# 59                                                 NaN            1.0
# 62   recent season__52__65###season__59__65###recen...            1.0
# 78                                                 NaN            3.0
# 108                                                NaN            1.0
# 111                                        now__20__23            2.0

# %%
# find the event tokens in each sentences without events
event_count = pd.read_csv("../../data/TempEval3-data/TE3-Platinum_events.csv", skip_blank_lines=True)
#event_count['Event']

subsetSentences['#Event Tokens'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        for k in range(len(event_count.index)):
            if (subset['Lowercase Token'].iloc[j] == event_count['Lowercase Token'].iloc[k]) & (subset['POS Tag'].iloc[j] == event_count['Pos'].iloc[k]):
                #print("true")
                count = count + 1
    subsetSentences['#Event Tokens'].iloc[i] = int(count)
# Out:
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/oanainel/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
subsetSentences.head(5)
# Out:
#                         Doc Id  Sentence Id  \
# 59                 AP_20130322           10
# 62                 AP_20130322           13
# 78         nyt_20130321_cyprus           12
# 108  nyt_20130321_women_senate            5
# 111  nyt_20130321_women_senate            8
#
#                                               Sentence  \
# 59   The government only does a national flu death ...
# 62   That 's more than 2 1/2 times higher than any ...
# 78   That is a mere rounding error compared with th...
# 108   `` There still just are n't that many of us . ''
# 111  A record nine women now lead committees , incl...
#
#                                     Lowercase Sentence  #Tokens  \
# 59   the government only does a national flu death ...       12
# 62   that 's more than 2 1/2 times higher than any ...       13
# 78   that is a mere rounding error compared with th...       17
# 108   `` there still just are n't that many of us . ''       12
# 111  a record nine women now lead committees , incl...       16
#
#                                       Stanford POS Tag  \
# 59                DT NN RB VBZ DT JJ NN NN NN IN NNS .
# 62           DT VBZ JJR IN CD NNS JJR IN DT JJ JJ NN .
# 78   DT VBZ DT JJ VBG NN VBN IN DT NN NN NN IN CD C...
# 108               `` EX RB RB VBP RB IN JJ IN PRP . ''
# 111  DT NN CD NNS RB VBP NNS , VBG DT IN DT RBS JJ ...
#
#                                         Stanford Lemma  \
# 59   the government only do a national flu death co...
# 62   that be more than 2 1/2 time higher than any o...
# 78   that be a mere round error compare with the eu...
# 108    `` there still just be not that many of we . ''
# 111  a record nine woman now lead committee , inclu...
#
#                                   Stanford Lower Lemma  #POS Tags  #Lemmas  \
# 59   the government only do a national flu death co...         12       12
# 62   that be more than 2 1/2 time higher than any o...         13       13
# 78   that be a mere round error compare with the eu...         17       17
# 108    `` there still just be not that many of we . ''         12       12
# 111  a record nine woman now lead committee , inclu...         16       16
#
#      #Events  #Time Expressions  \
# 59         0                  0
# 62         0                  1
# 78         0                  0
# 108        0                  0
# 111        0                  1
#
#                                         All Runs Times  # POS Tags VB  \
# 59                                                 NaN            1.0
# 62   recent season__52__65###season__59__65###recen...            1.0
# 78                                                 NaN            3.0
# 108                                                NaN            1.0
# 111                                        now__20__23            2.0
#
#      #Event Tokens
# 59             2.0
# 62             4.0
# 78             0.0
# 108            0.0
# 111            1.0

# %%
# find the event tokens in each sentences without events

subsetSentences['#Event Lemma'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        for k in range(len(event_count.index)):
            if (subset['Lowercase Lemma Stanford'].iloc[j] == event_count['Lowercase Lemma Stanford'].iloc[k]) & (subset['POS Tag'].iloc[j] == event_count['Pos'].iloc[k]):
                count = int(count) + 1
    subsetSentences['#Event Lemma'].iloc[i] = int(count)
# Out:
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/oanainel/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
event_count.head(5)
# Out:
#         Doc Id  Sentence Id  Event Id      Aspect  End Offset   Event Class  \
# 0  AP_20130322            0  e1000028        NONE          14  B-OCCURRENCE
# 1  AP_20130322            0        e2  PERFECTIVE          50  B-OCCURRENCE
# 2  AP_20130322            1        e3        NONE          18   B-ASPECTUAL
# 3  AP_20130322            1        e4        NONE          62   B-ASPECTUAL
# 4  AP_20130322            1        e5        NONE          85  B-OCCURRENCE
#
#   Event Id.1  Is Event Lemma Stanford Lowercase Lemma Stanford    ...      \
# 0   e1000028         1         season                   season    ...
# 1         e2         1           kill                     kill    ...
# 2         e3         1          start                    start    ...
# 3         e4         1          spark                    spark    ...
# 4         e5         1           turn                     turn    ...
#
#   POS Tag Stanford Polarity Pos Start Offset     Tense     Token Token Id Doc  \
# 0               NN      POS  NN            8      NONE    season            3
# 1              VBN      POS  VB           44   PRESENT    killed           11
# 2              VBD      POS  VB           11      PAST   started           24
# 3              VBG      POS  VB           54  PRESPART  sparking           32
# 4               VB      POS  VB           81      NONE      turn           36
#
#   Token Id Sent    Token POS  Lemma POS
# 0             3    season-NN  season-NN
# 1            11    killed-VB    kill-VB
# 2             3   started-VB   start-VB
# 3            11  sparking-VB   spark-VB
# 4            15      turn-VB    turn-VB
#
# [5 rows x 21 columns]

# %%
subsetSentences.head(5)
# Out:
#                         Doc Id  Sentence Id  \
# 59                 AP_20130322           10
# 62                 AP_20130322           13
# 78         nyt_20130321_cyprus           12
# 108  nyt_20130321_women_senate            5
# 111  nyt_20130321_women_senate            8
#
#                                               Sentence  \
# 59   The government only does a national flu death ...
# 62   That 's more than 2 1/2 times higher than any ...
# 78   That is a mere rounding error compared with th...
# 108   `` There still just are n't that many of us . ''
# 111  A record nine women now lead committees , incl...
#
#                                     Lowercase Sentence  #Tokens  \
# 59   the government only does a national flu death ...       12
# 62   that 's more than 2 1/2 times higher than any ...       13
# 78   that is a mere rounding error compared with th...       17
# 108   `` there still just are n't that many of us . ''       12
# 111  a record nine women now lead committees , incl...       16
#
#                                       Stanford POS Tag  \
# 59                DT NN RB VBZ DT JJ NN NN NN IN NNS .
# 62           DT VBZ JJR IN CD NNS JJR IN DT JJ JJ NN .
# 78   DT VBZ DT JJ VBG NN VBN IN DT NN NN NN IN CD C...
# 108               `` EX RB RB VBP RB IN JJ IN PRP . ''
# 111  DT NN CD NNS RB VBP NNS , VBG DT IN DT RBS JJ ...
#
#                                         Stanford Lemma  \
# 59   the government only do a national flu death co...
# 62   that be more than 2 1/2 time higher than any o...
# 78   that be a mere round error compare with the eu...
# 108    `` there still just be not that many of we . ''
# 111  a record nine woman now lead committee , inclu...
#
#                                   Stanford Lower Lemma  #POS Tags  #Lemmas  \
# 59   the government only do a national flu death co...         12       12
# 62   that be more than 2 1/2 time higher than any o...         13       13
# 78   that be a mere round error compare with the eu...         17       17
# 108    `` there still just be not that many of we . ''         12       12
# 111  a record nine woman now lead committee , inclu...         16       16
#
#      #Events  #Time Expressions  \
# 59         0                  0
# 62         0                  1
# 78         0                  0
# 108        0                  0
# 111        0                  1
#
#                                         All Runs Times  # POS Tags VB  \
# 59                                                 NaN            1.0
# 62   recent season__52__65###season__59__65###recen...            1.0
# 78                                                 NaN            3.0
# 108                                                NaN            1.0
# 111                                        now__20__23            2.0
#
#      #Event Tokens  #Event Lemma
# 59             2.0           6.0
# 62             4.0           7.0
# 78             0.0           4.0
# 108            0.0           2.0
# 111            1.0           7.0

# %%
subsetSentences = subsetSentences.sort_values(by='#Tokens')
subsetSentences.to_csv('../../data/TempEval3-data/TE3-Platinum_subset_sentences_without_events.csv', index=False)

# %%
subsetSentences = pd.read_csv('../../data/TempEval3-data/TE3-Platinum_subset_sentences_without_events.csv')

# %%
subsetSentences.head(5)
# Out:
#               Doc Id  Sentence Id  \
# 0   CNN_20130321_821            5
# 1  WSJ_20130321_1145            9
# 2  CNN_20130322_1243           11
# 3  CNN_20130322_1243           21
# 4  bbc_20130322_1150            7
#
#                                             Sentence  \
# 0                              They have an agenda .
# 1                           But Leon can still run .
# 2            The entire experience is frictionless .
# 3            But it is a well-exectuted refinement .
# 4  `` There was a great feeling of euphoria from ...
#
#                                   Lowercase Sentence  #Tokens  \
# 0                              they have an agenda .        5
# 1                           but leon can still run .        6
# 2            the entire experience is frictionless .        6
# 3            but it is a well-exectuted refinement .        7
# 4  `` there was a great feeling of euphoria from ...       11
#
#                    Stanford POS Tag  \
# 0                   PRP VBP DT NN .
# 1                 CC NNP MD RB VB .
# 2                 DT JJ NN VBZ JJ .
# 3             CC PRP VBZ DT JJ NN .
# 4  `` EX VBD DT JJ NN IN NN IN NN .
#
#                                       Stanford Lemma  \
# 0                               they have a agenda .
# 1                           but Leon can still run .
# 2            the entire experience be frictionless .
# 3            but it be a well-exectuted refinement .
# 4  `` there be a great feeling of euphoria from e...
#
#                                 Stanford Lower Lemma  #POS Tags  #Lemmas  \
# 0                               they have a agenda .          5        5
# 1                           but leon can still run .          6        6
# 2            the entire experience be frictionless .          6        6
# 3            but it be a well-exectuted refinement .          7        7
# 4  `` there be a great feeling of euphoria from e...         11       11
#
#    #Events  #Time Expressions All Runs Times  # POS Tags VB  #Event Tokens  \
# 0        0                  0            NaN            1.0            4.0
# 1        0                  0            NaN            1.0            1.0
# 2        0                  0            NaN            1.0            0.0
# 3        0                  0            NaN            1.0            0.0
# 4        0                  0            NaN            1.0            1.0
#
#    #Event Lemma
# 0           8.0
# 1           1.0
# 2           2.0
# 3           2.0
# 4           2.0

# %%
subsetSentences = subsetSentences.reset_index()

# %%
ax = plt.gca()

# add the second axis
ax2 = ax.twinx()

lns1 = ax.plot(subsetSentences['#Tokens'], 'o', c='forestgreen', lw=2.5, label = '# Tokens')
lns2 = ax2.plot(subsetSentences['# POS Tags VB'], 'o', color='red', ms=2.5, label = '# VB - POS Tags')
lns3 = ax2.plot(subsetSentences['#Event Lemma'], 'x', ms=4, color='royalblue', label = '# Event Lemma')

# prepare and plot the trend line
difference = subsetSentences['#Event Lemma'] - subsetSentences['# POS Tags VB']
z = np.polyfit(subsetSentences['index'], difference,2)
p = np.poly1d(z)
lns4 = ax2.plot(subsetSentences['index'], p(subsetSentences['index']),'k-', label = 'Trend')

# add grid to the chart
ax.grid(True)

# setup the label for each axis
ax.set_xlabel('Sentence Index', fontsize=14, color='black')  
ax.set_ylabel('# Tokens', fontsize=14, color='black')  
ax2.set_ylabel('# Potential Events', fontsize=14, color='black') 

# added the four lines in the legend
lns = lns1+lns2+lns3+lns4
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0, prop={'size':13})

#plt.legend(prop={'size':13})
#plt.show()

plt.savefig('unlabeled_sentences_platinum_stats.pdf', format='pdf', dpi=1200)

# %%
min(subsetSentences["#Tokens"])
# Out:
# 2

# %%
max(subsetSentences["#Tokens"])
# Out:
# 63

# %%
sum(subsetSentences["#Tokens"])/len(subsetSentences["#Tokens"])
# Out:
# 16.310541310541311

# %%
min(subsetSentences['# POS Tags VB'])
# Out:
# 0.0

# %%
max(subsetSentences['# POS Tags VB'])
# Out:
# 8.0

# %%
sum(subsetSentences["# POS Tags VB"])/len(subsetSentences["# POS Tags VB"])
# Out:
# 1.7692307692307692

# %%
min(subsetSentences['#Event Tokens'])
# Out:
# 0.0

# %%
max(subsetSentences['#Event Tokens'])
# Out:
# 15.0

# %%
sum(subsetSentences["#Event Tokens"])/len(subsetSentences["#Event Tokens"])
# Out:
# 2.8205128205128207

# %%
min(subsetSentences['#Event Lemma'])
# Out:
# 0.0

# %%
max(subsetSentences['#Event Lemma'])
# Out:
# 16.0

# %%
sum(subsetSentences["#Event Lemma"])/len(subsetSentences["#Event Lemma"])
# Out:
# 3.1396011396011394

# %%
ax = plt.gca()
ax2 = ax.twinx()

difference = subsetSentences['#Event Lemma'] - subsetSentences['# POS Tags VB']
z = np.polyfit(subsetSentences['index'], difference,2)
p = np.poly1d(z)


plt.ylim(0, 16)
ax.plot(subsetSentences['#Tokens'], c='green', lw=4)
ax2.plot(subsetSentences['#Event Lemma'] - subsetSentences['# POS Tags VB'], 'o', color='r', ms=2.5)
#ax2.plot(subsetSentences['# Event Tokens'])
#ax2.plot(subsetSentences['# Event Lemma'], 'x', ms=4, color='b')

ax2.plot(subsetSentences['index'], p(subsetSentences['index']),'k-')
ax.grid(True)
#plt.title("Potential Event Distribution per Unlabeled Expert Sentence ", fontsize=20,color='black')
ax.set_xlabel('Sentence Index', fontsize=14, color='black')  
ax.set_ylabel('# Tokens', fontsize=14, color='black')  
ax2.set_ylabel('# Potential Events', fontsize=14, color='black') 
plt.show()

# %%
subsetSentences
subsetSentences = subsetSentences.sort_values('#Event Tokens', ascending=[1])
subsetSentences = subsetSentences.reset_index(drop=True)

# %%
plt.plot(subsetSentences.index, subsetSentences['#Tokens'], "o", c="forestgreen", lw=2.5, label = 'Total # Tokens')
plt.plot(subsetSentences.index, subsetSentences['#Event Tokens'], "o", ms=4, color='red', label = '# Event Tokens')

# prepare and plot the trend line
difference = subsetSentences['#Tokens'] - subsetSentences['#Event Tokens']
z = np.polyfit(subsetSentences.index, difference,2)
p = np.poly1d(z)
lns4 = plt.plot(subsetSentences.index, p(subsetSentences.index),'k-', label = 'Trend')

# add grid to the chart
plt.grid(True)

# setup the label for each axis
plt.xlabel('Sentence Index', fontsize=14, color='black')  
plt.ylabel('Tokens', fontsize=14, color='black')  

plt.legend(loc='upper left')

# %%
subsetSentences
subsetSentences = subsetSentences.sort_values('#Event Lemma', ascending=[1])
subsetSentences = subsetSentences.reset_index(drop=True)

# %%
plt.plot(subsetSentences.index, subsetSentences['#Tokens'], "o", c="forestgreen", lw=2.5, label = 'Total # Lemmas')
plt.plot(subsetSentences.index, subsetSentences['#Event Lemma'], "o", ms=4, color='red', label = '# Event Lemmas')

# prepare and plot the trend line
difference = subsetSentences['#Tokens'] - subsetSentences['#Event Lemma']
z = np.polyfit(subsetSentences.index, difference,2)
p = np.poly1d(z)
lns4 = plt.plot(subsetSentences.index, p(subsetSentences.index),'k-', label = 'Trend')

# add grid to the chart
plt.grid(True)

# setup the label for each axis
plt.xlabel('Sentence Index', fontsize=14, color='black')  
plt.ylabel('Lemmas', fontsize=14, color='black')  

plt.legend(loc='upper left')
plt.show()

# %%
sentences = pd.read_csv("../../data/TempEval3-data/TE3-Gold_sentences.csv")
subsetSentences = sentences[sentences['#Events'] == 0]

tokens = pd.read_csv("../../data/TempEval3-data/TE3-Gold_tokens.csv", skip_blank_lines=True)
subsetTokens = pd.DataFrame()

for i in range(len(subsetSentences.index)):
    subset = tokens[(tokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (tokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    frames = [subsetTokens, subset]
    subsetTokens = pd.concat(frames)

# %%
sum(subsetSentences['#Tokens'])
# Out:
# 5694

# %%
sLength = len(subsetSentences['Doc Id'])
subsetSentences['# POS Tags VB'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        if ('VB' in subset['POS Tag'].iloc[j]):
            count = count + 1
    
    subsetSentences['# POS Tags VB'].iloc[i] = int(count)
# Out:
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/oanainel/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
# find the event tokens in each sentences without events
event_count = pd.read_csv("../../data/TempEval3-data/TE3-Gold_events.csv", skip_blank_lines=True)
#event_count['Event']

subsetSentences['#Event Tokens'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        for k in range(len(event_count.index)):
            if (subset['Lowercase Token'].iloc[j] == event_count['Lowercase Token'].iloc[k]) & (subset['POS Tag'].iloc[j] == event_count['Pos'].iloc[k]):
                #print("true")
                count = count + 1
    subsetSentences['#Event Tokens'].iloc[i] = int(count)
# Out:
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/oanainel/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/oanainel/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
# find the event tokens in each sentences without events

subsetSentences['#Event Lemma'] = pd.Series(np.random.randn(sLength), index=subsetSentences.index)

for i in range(len(subsetSentences.index)):
    
    subset = subsetTokens[(subsetTokens['Doc Id'] == subsetSentences['Doc Id'].iloc[i]) & (subsetTokens['Sentence Id'] == subsetSentences['Sentence Id'].iloc[i])]
    count = 0
    for j in range(len(subset.index)):
        for k in range(len(event_count.index)):
            if (subset['Lowercase Lemma Stanford'].iloc[j] == event_count['Lowercase Lemma Stanford'].iloc[k]) & (subset['POS Tag'].iloc[j] == event_count['Pos'].iloc[k]):
                count = int(count) + 1
    subsetSentences['#Event Lemma'].iloc[i] = int(count)

# %%
subsetSentences = subsetSentences.sort_values(by='#Tokens')
subsetSentences.to_csv('../../data/TempEval3-data/TE3-Gold_subset_sentences_without_events.csv', index=False)

# %%
subsetSentences = subsetSentences.reset_index()

# %%
ax = plt.gca()

# add the second axis
ax2 = ax.twinx()

lns1 = ax.plot(subsetSentences['#Tokens'], 'o', c='forestgreen', lw=2.5, label = '# Tokens')
lns2 = ax2.plot(subsetSentences['# POS Tags VB'], 'o', color='red', ms=2.5, label = '# VB - POS Tags')
lns3 = ax2.plot(subsetSentences['#Event Lemma'], 'x', ms=4, color='royalblue', label = '# Event Lemma')

# prepare and plot the trend line
difference = subsetSentences['#Event Lemma'] - subsetSentences['# POS Tags VB']
z = np.polyfit(subsetSentences['index'], difference,2)
p = np.poly1d(z)
lns4 = ax2.plot(subsetSentences['index'], p(subsetSentences['index']),'k-', label = 'Trend')

# add grid to the chart
ax.grid(True)

# setup the label for each axis
ax.set_xlabel('Sentence Index', fontsize=14, color='black')  
ax.set_ylabel('# Tokens', fontsize=14, color='black')  
ax2.set_ylabel('# Potential Events', fontsize=14, color='black') 

# added the four lines in the legend
lns = lns1+lns2+lns3+lns4
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0, prop={'size':13})

#plt.legend(prop={'size':13})
#plt.show()

plt.savefig('unlabeled_sentences_gold_stats.pdf', format='pdf', dpi=1200)
